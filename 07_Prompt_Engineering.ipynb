# %% [markdown]
# ## Prompt Optimization techniques

# %%
import requests
import pandas as pd
import numpy as np
import re
import warnings
warnings.filterwarnings("ignore")

from openai import OpenAI

# %%
requests.get("http://localhost:11434").content

OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

model_name="llama3.2"

# %%
from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama
#from langchain.memory import ConversationBufferMemory
from langchain_core.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_classic.chains import ConversationChain
from langchain_classic.memory import ConversationBufferMemory

# %%
# Initialize the Ollama model
llm = ChatOllama(
    model=model_name,   # change to mistral / qwen2.5 if you want
    temperature=0
)

# %%
# Define a helper function to generate responses
def generate_response(prompt):
    """Generate a response using the language model.

    Args:
        prompt (str): The input prompt.

    Returns:
        str: The generated response.
    """
    return llm.invoke(prompt).content

# %% [markdown]
# ## A/B Testing Prompts

# %%
# Define prompt variations
prompt_a = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms."
)

prompt_b = PromptTemplate(
    input_variables=["topic"],
    template="Provide a beginner-friendly explanation of {topic}, including key concepts and an example."
)

# Updated function to evaluate response quality
def evaluate_response(response, criteria):
    """Evaluate the quality of a response based on given criteria.

    Args:
        response (str): The generated response.
        criteria (list): List of criteria to evaluate.

    Returns:
        float: The average score across all criteria.
    """
    scores = []
    for criterion in criteria:
        print(f"Evaluating response based on {criterion}...")
        prompt = f"On a scale of 1-10, rate the following response on {criterion}. Start your response with the numeric score:\n\n{response}"
        response = generate_response(prompt)
        # show 50 characters of the response
        # Use regex to find the first number in the response
        score_match = re.search(r'\d+', response)
        if score_match:
            score = int(score_match.group())
            scores.append(min(score, 10))  # Ensure score is not greater than 10
        else:
            print(f"Warning: Could not extract numeric score for {criterion}. Using default score of 5.")
            scores.append(5)  # Default score if no number is found
    return np.mean(scores)

# Perform A/B test
topic = "machine learning"
response_a = generate_response(prompt_a.format(topic=topic))
response_b = generate_response(prompt_b.format(topic=topic))

criteria = ["clarity", "informativeness", "engagement"]
score_a = evaluate_response(response_a, criteria)
score_b = evaluate_response(response_b, criteria)

print(f"Prompt A score: {score_a:.2f}")
print(f"Prompt B score: {score_b:.2f}")
print(f"Winning prompt: {'A' if score_a > score_b else 'B'}")
# Out:
# Evaluating response based on clarity...
# Evaluating response based on informativeness...
# Evaluating response based on engagement...
# Evaluating response based on clarity...
# Evaluating response based on informativeness...
# Evaluating response based on engagement...
# Prompt A score: 8.00
# Prompt B score: 8.00
# Winning prompt: B

# %% [markdown]
# ## Iterative Refinement

# %%
import re

def sanitize_template(template: str) -> str:
    """Escape all curly braces that are NOT the {topic} placeholder."""
    # Find all placeholders in the template
    placeholders = re.findall(r'\{(.*?)\}', template)
    for p in placeholders:
        if p != 'topic':
            # Escape by doubling the braces so formatter ignores them
            template = template.replace('{' + p + '}', '{{' + p + '}}')
    return template


def refine_prompt(initial_prompt, topic, iterations=3):
    current_prompt = initial_prompt

    for i in range(iterations):
        # Sanitize before attempting format
        current_prompt.template = sanitize_template(current_prompt.template)

        try:
            response = generate_response(current_prompt.format(topic=topic))
        except KeyError as e:
            print(f"Error in iteration {i+1}: Missing key {e}. Adjusting prompt...")
            # Fallback: escape the offending key and retry
            bad_key = e.args[0]
            current_prompt.template = current_prompt.template.replace(
                '{' + bad_key + '}', '{{' + bad_key + '}}'
            )
            response = generate_response(current_prompt.format(topic=topic))

        # Generate feedback
        feedback_prompt = (
            f"Analyze the following explanation of {topic} and suggest "
            f"improvements to the prompt that generated it:\n\n{response}"
        )
        feedback = generate_response(feedback_prompt)

        # Refine the prompt — explicitly instruct LLM to avoid extra braces
        refine_prompt_text = (
            f"Based on this feedback: '{feedback}', improve the following prompt template.\n"
            f"IMPORTANT: Use ONLY the placeholder {{topic}} in your template. "
            f"Do NOT use any other curly braces or placeholders.\n\n"
            f"{current_prompt.template}"
        )
        refined_template = generate_response(refine_prompt_text)

        # Sanitize the LLM output before creating new PromptTemplate
        refined_template = sanitize_template(refined_template)

        current_prompt = PromptTemplate(
            input_variables=["topic"],
            template=refined_template
        )

        print(f"Iteration {i+1} prompt:\n{current_prompt.template}\n")

    return current_prompt


# Perform A/B test
topic = "machine learning"
response_a = generate_response(prompt_a.format(topic=topic))
response_b = generate_response(prompt_b.format(topic=topic))

criteria = ["clarity", "informativeness", "engagement"]
score_a = evaluate_response(response_a, criteria)
score_b = evaluate_response(response_b, criteria)

print(f"Prompt A score: {score_a:.2f}")
print(f"Prompt B score: {score_b:.2f}")
print(f"Winning prompt: {'A' if score_a > score_b else 'B'}")

# Start with the winning prompt from A/B testing
initial_prompt = prompt_b if score_b > score_a else prompt_a
refined_prompt = refine_prompt(initial_prompt, "machine learning")

print("\nFinal refined prompt:")
print(refined_prompt.template)
# Out:
# Evaluating response based on clarity...
# Evaluating response based on informativeness...
# Evaluating response based on engagement...
# Evaluating response based on clarity...
# Evaluating response based on informativeness...
# Evaluating response based on engagement...
# Prompt A score: 8.00
# Prompt B score: 8.00
# Winning prompt: B
# Iteration 1 prompt:
# Imagine you're teaching a child to recognize different animals. You show them pictures of dogs, cats, and birds, and say "this is a dog" or "this is a cat". At first, the child might not be very good at recognizing the animals, but as they see more and more pictures, they start to get better.
#
# {topic} works in a similar way. A computer is shown a large number of examples, such as images of dogs and cats, and it tries to figure out the characteristics that make them different. This process involves identifying patterns and relationships between the examples, which allows the computer to learn from its mistakes and improve over time.
#
# There are three main types of {topic}:
#
# 1. **Supervised learning**: The computer is shown examples with labels, such as "this is a dog", and it tries to learn from those labels.
# 2. **Unsupervised learning**: The computer is shown examples without labels, but it still tries to find patterns and relationships between them.
# 3. **Reinforcement learning**: The computer learns by interacting with the environment and getting feedback in the form of rewards or penalties.
#
# {topic} has many applications, such as:
#
# * Image recognition (like self-driving cars): {topic} algorithms can analyze images of roads and traffic lights to detect obstacles and make decisions about navigation.
# * Speech recognition (like virtual assistants): {topic} models can learn to recognize patterns in speech and generate responses that sound natural and human-like.
# * Predictive modeling (like forecasting sales or weather): {topic} algorithms can analyze historical data and make predictions about future trends.
#
# Overall, {topic} is a powerful tool that allows computers to learn and improve on their own. By understanding how it works, we can unlock its full potential and create more efficient and effective systems in many areas of life.
#
# Iteration 2 prompt:
# {topic}
#
# Imagine you're teaching a child to recognize different animals. You show them pictures of dogs, cats, and birds, and say "this is a dog" or "this is a cat". At first, the child might not be very good at recognizing the animals, but as they see more and more pictures, they start to get better.
#
# {topic} works in a similar way. A computer is shown a large number of examples, such as images of dogs and cats, and it tries to figure out the characteristics that make them different. This process involves identifying patterns and relationships between the examples, which allows the computer to learn from its mistakes and improve over time.
#
# There are three main types of {topic}:
#
# 1. **Supervised learning**: The computer is shown examples with labels, such as "this is a dog", and it tries to learn from those labels.
# 2. **Unsupervised learning**: The computer is shown examples without labels, but it still tries to find patterns and relationships between them.
# 3. **Reinforcement learning**: The computer learns by interacting with the environment and getting feedback in the form of rewards or penalties.
#
# {topic} has many applications, such as:
#
# * Image recognition (like self-driving cars): {topic} algorithms can analyze images of roads and traffic lights to detect obstacles and make decisions about navigation.
# * Speech recognition (like virtual assistants): {topic} models can learn to recognize patterns in speech and generate responses that sound natural and human-like.
# * Predictive modeling (like forecasting sales or weather): {topic} algorithms can analyze historical data and make predictions about future trends.
#
# To illustrate the concept of supervised learning, consider a scenario where a computer is trained on a dataset of images of dogs and cats. The computer is shown each image with a label indicating whether it's a dog or a cat. As the computer sees more examples, it starts to recognize patterns in the images and can accurately classify new, unseen images as either dogs or cats.
#
# Similarly, unsupervised learning involves clustering customers based on their buying behavior without any prior labels or rules. The computer analyzes the data and identifies patterns and relationships between the customers, allowing it to group them into categories that are meaningful for business purposes.
#
# Reinforcement learning is a more complex type of {topic} that involves interacting with an environment and receiving feedback in the form of rewards or penalties. For example, a self-driving car learns by navigating through roads and receiving feedback in the form of rewards (e.g., arriving at a destination safely) or penalties (e.g., crashing into another vehicle). This process allows the computer to learn from its mistakes and improve over time.
#
# Overall, {topic} is a powerful tool that allows computers to learn and improve on their own. By understanding how it works, we can unlock its full potential and create more efficient and effective systems in many areas of life.
#
# Iteration 3 prompt:
# {topic}
#
# Imagine you're teaching a child to recognize different animals. You show them pictures of dogs, cats, and birds, and say "this is a dog" or "this is a cat". At first, the child might not be very good at recognizing the animals, but as they see more and more pictures, they start to get better.
#
# {topic} works in a similar way. A computer is shown a large number of examples, such as images of dogs and cats, and it tries to figure out the characteristics that make them different. This process involves identifying patterns and relationships between the examples, which allows the computer to learn from its mistakes and improve over time.
#
# There are three main types of {topic}:
#
# 1. **Supervised learning**: The computer is shown examples with labels, such as "this is a dog", and it tries to learn from those labels.
# 2. **Unsupervised learning**: The computer is shown examples without labels, but it still tries to find patterns and relationships between them.
# 3. **Reinforcement learning**: The computer learns by interacting with the environment and getting feedback in the form of rewards or penalties.
#
# {topic} has many applications, such as:
#
# * Image recognition (like self-driving cars): {topic} algorithms can analyze images of roads and traffic lights to detect obstacles and make decisions about navigation.
# * Speech recognition (like virtual assistants): {topic} models can learn to recognize patterns in speech and generate responses that sound natural and human-like.
# * Predictive modeling (like forecasting sales or weather): {topic} algorithms can analyze historical data and make predictions about future trends.
#
# To illustrate the concept of supervised learning, consider a scenario where a computer is trained on a dataset of images of dogs and cats. The computer is shown each image with a label indicating whether it's a dog or a cat. As the computer sees more examples, it starts to recognize patterns in the images and can accurately classify new, unseen images as either dogs or cats.
#
# Similarly, unsupervised learning involves clustering customers based on their buying behavior without any prior labels or rules. The computer analyzes the data and identifies patterns and relationships between the customers, allowing it to group them into categories that are meaningful for business purposes.
#
# Reinforcement learning is a more complex type of {topic} that involves interacting with an environment and receiving feedback in the form of rewards or penalties. For example, a self-driving car learns by navigating through roads and receiving feedback in the form of rewards (e.g., arriving at a destination safely) or penalties (e.g., crashing into another vehicle). This process allows the computer to learn from its mistakes and improve over time.
#
# Overall, {topic} is a powerful tool that allows computers to learn and improve on their own. By understanding how it works, we can unlock its full potential and create more efficient and effective systems in many areas of life.
#
#
# Final refined prompt:
# {topic}
#
# Imagine you're teaching a child to recognize different animals. You show them pictures of dogs, cats, and birds, and say "this is a dog" or "this is a cat". At first, the child might not be very good at recognizing the animals, but as they see more and more pictures, they start to get better.
#
# {topic} works in a similar way. A computer is shown a large number of examples, such as images of dogs and cats, and it tries to figure out the characteristics that make them different. This process involves identifying patterns and relationships between the examples, which allows the computer to learn from its mistakes and improve over time.
#
# There are three main types of {topic}:
#
# 1. **Supervised learning**: The computer is shown examples with labels, such as "this is a dog", and it tries to learn from those labels.
# 2. **Unsupervised learning**: The computer is shown examples without labels, but it still tries to find patterns and relationships between them.
# 3. **Reinforcement learning**: The computer learns by interacting with the environment and getting feedback in the form of rewards or penalties.
#
# {topic} has many applications, such as:
#
# * Image recognition (like self-driving cars): {topic} algorithms can analyze images of roads and traffic lights to detect obstacles and make decisions about navigation.
# * Speech recognition (like virtual assistants): {topic} models can learn to recognize patterns in speech and generate responses that sound natural and human-like.
# * Predictive modeling (like forecasting sales or weather): {topic} algorithms can analyze historical data and make predictions about future trends.
#
# To illustrate the concept of supervised learning, consider a scenario where a computer is trained on a dataset of images of dogs and cats. The computer is shown each image with a label indicating whether it's a dog or a cat. As the computer sees more examples, it starts to recognize patterns in the images and can accurately classify new, unseen images as either dogs or cats.
#
# Similarly, unsupervised learning involves clustering customers based on their buying behavior without any prior labels or rules. The computer analyzes the data and identifies patterns and relationships between the customers, allowing it to group them into categories that are meaningful for business purposes.
#
# Reinforcement learning is a more complex type of {topic} that involves interacting with an environment and receiving feedback in the form of rewards or penalties. For example, a self-driving car learns by navigating through roads and receiving feedback in the form of rewards (e.g., arriving at a destination safely) or penalties (e.g., crashing into another vehicle). This process allows the computer to learn from its mistakes and improve over time.
#
# Overall, {topic} is a powerful tool that allows computers to learn and improve on their own. By understanding how it works, we can unlock its full potential and create more efficient and effective systems in many areas of life.

# %% [markdown]
# ## Comparing Original and Refined Prompts

# %%
original_response = generate_response(initial_prompt.format(topic="machine learning"))
refined_prompt = generate_response(refined_prompt.format(topic="machine learning"))

original_score = evaluate_response(original_response, criteria)
refined_score = evaluate_response(refined_prompt, criteria)

print(f"Original prompt score: {original_score:.2f}")
print(f"Refined prompt score: {refined_score:.2f}")
print(f"Improvement: {(refined_score - original_score):.2f} points")
# Out:
# Evaluating response based on clarity...
# Evaluating response based on informativeness...
# Evaluating response based on engagement...
# Evaluating response based on clarity...
# Evaluating response based on informativeness...
# Evaluating response based on engagement...
# Original prompt score: 8.00
# Refined prompt score: 8.00
# Improvement: 0.00 points

# %% [markdown]
# # Handling Ambiguity  and  Improving Clarity in Prompt Engineering

# %%
ambiguous_prompts = [
    "Tell me about the bank.",
    "What's the best way to get to school?",
    "Can you explain the theory?"
]

for prompt in ambiguous_prompts:
    analysis_prompt = f"Analyze the following prompt for ambiguity: '{prompt}'. Explain why it's ambiguous and list possible interpretations."
    print(f"Prompt: {prompt}")
    print(llm.invoke(analysis_prompt).content)
    print("-" * 50)
# Out:
# Prompt: Tell me about the bank.
# The prompt "Tell me about the bank" is ambiguous because it lacks specificity, leaving room for multiple interpretations. Here are some reasons why:
#
# 1. **Lack of clarity**: The word "bank" can refer to a financial institution (e.g., a commercial bank), a riverbank, or even a storage location for data (a database). Without further context, it's unclear which meaning is intended.
# 2. **Multiple possible meanings**: There are at least three common interpretations of the term "bank":
# 	* A financial institution providing banking services (e.g., depositing, lending, and investing).
# 	* The side or edge of a river or lake.
# 	* A storage location for data or information.
# 3. **Contextual dependence**: The interpretation of "bank" depends on the context in which it is used. For example:
# 	* In a financial setting, "Tell me about the bank" might refer to a specific commercial bank or a banking industry as a whole.
# 	* In a geographical setting, "Tell me about the bank" might refer to a riverbank or a specific location along a waterway.
# 	* In an IT setting, "Tell me about the bank" might refer to a database or data storage system.
#
# Possible interpretations of the prompt include:
#
# 1. **Financial institution**: The speaker wants information about a specific commercial bank, its services, products, and policies.
# 2. **Riverbank**: The speaker is interested in learning about the geography and ecology of a riverbank, perhaps for recreational or environmental purposes.
# 3. **Data storage**: The speaker wants to know more about a database or data storage system used by an organization or institution.
# 4. **General information**: The speaker simply wants general information about banks, such as their history, role in society, or current trends.
#
# To clarify the intended meaning, additional context or specification would be necessary, such as "Tell me about the commercial bank on Main Street" or "I'm interested in learning about riverbank ecosystems."
# --------------------------------------------------
# Prompt: What's the best way to get to school?
# The prompt "What's the best way to get to school?" is ambiguous because it lacks specificity about the context, location, and individual involved. Here are some reasons why:
#
# 1. **Lack of geographical information**: The prompt doesn't specify which school or location the person is referring to. This makes it unclear whether they're asking about getting to a local school, a distant school, or even a different type of institution (e.g., university).
# 2. **Unclear mode of transportation**: The prompt doesn't mention how the person plans to get to school. Are they driving, walking, biking, taking public transportation, or using another method? This ambiguity makes it difficult to provide a specific answer.
# 3. **No consideration for individual circumstances**: The prompt doesn't take into account any personal factors that might influence the best way to get to school, such as physical limitations, mobility issues, or special needs.
#
# Possible interpretations of this prompt include:
#
# 1. **General advice**: A person asking about the most efficient or convenient way to get to a school in general, without specifying their own circumstances.
# 2. **Personal question**: An individual asking for guidance on how to get to their specific school, taking into account their own needs and preferences (e.g., "What's the best way to get to my school if I have a disability?").
# 3. **Commuting advice**: A person seeking general advice on how to commute to work or another regular destination that might be similar to school.
# 4. **School-related inquiry**: A student asking about transportation options for getting to school, but not necessarily considering their own needs (e.g., "What's the best way to get to school if I'm late?").
# 5. **Context-dependent question**: The prompt is part of a larger conversation or context that provides additional information about the individual's situation and the specific circumstances they're facing.
#
# To provide a more accurate answer, it would be helpful to clarify the context, location, and individual involved in the prompt.
# --------------------------------------------------
# Prompt: Can you explain the theory?
# The prompt "Can you explain the theory?" is somewhat ambiguous because it lacks specificity about what theory is being referred to. Here are some reasons why:
#
# 1. Lack of context: The prompt doesn't provide any context or information about the theory in question, making it difficult to determine which theory is being asked about.
# 2. Vagueness: The word "theory" can refer to a wide range of concepts, from scientific hypotheses to philosophical ideas, and even abstract concepts like theories of mind or social constructs.
#
# Possible interpretations of the prompt include:
#
# 1. **Scientific theory**: The user might be asking for an explanation of a specific scientific concept, such as the theory of evolution or the Big Bang theory.
# 2. **Philosophical theory**: The user could be referring to a philosophical idea, like Plato's Theory of Forms or Aristotle's theory of causality.
# 3. **Abstract concept**: The user might be asking about a more abstract concept, like the theory of relativity (Einstein's) or the theory of mind (cognitive psychology).
# 4. **Academic theory**: The user could be referring to a specific academic discipline, such as literary theory, sociological theory, or economic theory.
# 5. **General knowledge**: The user might simply be asking for an explanation of a general concept, like the theory of gravity or the theory of happiness.
#
# To clarify the prompt, additional context or information would be necessary, such as:
#
# * "Can you explain the theory of evolution?"
# * "Can you explain Plato's Theory of Forms?"
# * "Can you explain the theory of relativity?"
#
# By providing more context, the user can help ensure that the response is relevant and accurate.
# --------------------------------------------------

# %% [markdown]
# ## Resolving Ambiguity

# %%
def resolve_ambiguity(prompt, context):
    """
    Resolve ambiguity in a prompt by providing additional context.
    
    Args:
    prompt (str): The original ambiguous prompt
    context (str): Additional context to resolve ambiguity
    
    Returns:
    str: The AI's response to the clarified prompt
    """
    clarified_prompt = f"{context}\n\nBased on this context, {prompt}"
    return llm.invoke(clarified_prompt).content

# Example usage
ambiguous_prompt = "Tell me about the bank."
contexts = [
    "You are a financial advisor discussing savings accounts.",
    "You are a geographer describing river formations."
]

for context in contexts:
    print(f"Context: {context}")
    print(f"Clarified response: {resolve_ambiguity(ambiguous_prompt, context)}")
    print("-" * 50)
# Out:
# Context: You are a financial advisor discussing savings accounts.
# Clarified response: As a financial advisor, I'd be happy to discuss savings accounts with you.
#
# When it comes to choosing a bank for your savings account, there are several factors to consider. Here are some key things to look for:
#
# 1. **Interest Rates**: Look for banks that offer competitive interest rates on their savings accounts. While rates can fluctuate over time, a higher rate can help your money grow faster.
# 2. **Fees**: Be aware of any fees associated with the account, such as maintenance fees, overdraft fees, or ATM fees. Some banks may charge these fees, while others may not.
# 3. **Minimum Balance Requirements**: Some savings accounts require you to maintain a minimum balance to avoid fees or earn interest. Make sure you understand the requirements and can meet them easily.
# 4. **Accessibility**: Consider the bank's online and mobile banking capabilities. Can you access your account easily from anywhere? Are there mobile apps that allow you to deposit checks, transfer funds, or pay bills?
# 5. **Security**: Look for banks with robust security measures in place, such as encryption, two-factor authentication, and FDIC insurance (Federal Deposit Insurance Corporation).
# 6. **Customer Service**: Choose a bank with good customer service, including phone support, email support, and in-person assistance.
# 7. **Rewards and Incentives**: Some banks offer rewards or incentives for maintaining certain balances or meeting specific criteria.
#
# When selecting a bank for your savings account, consider your individual needs and priorities. Do you want a high-yield interest rate? Are you looking for low fees? Do you need easy online access?
#
# Some popular types of savings accounts include:
#
# * High-Yield Savings Accounts: These accounts offer higher interest rates than traditional savings accounts.
# * Money Market Accounts: These accounts often come with debit cards and check-writing privileges, making them a good option for those who want to earn interest while still having easy access to their funds.
# * Online Savings Accounts: These accounts are designed specifically for online banking and may offer competitive interest rates.
#
# Ultimately, the best bank for you will depend on your individual financial goals and needs. As a financial advisor, I'd be happy to help you explore your options and find the best savings account for you!
# --------------------------------------------------
# Context: You are a geographer describing river formations.
# Clarified response: The bank of a river is a fascinating feature that plays a crucial role in shaping its course and character. A river's bank refers to the sloping or vertical edge of land that borders the river channel. The bank can be composed of various materials, such as soil, sand, gravel, or rock, which are eroded and deposited over time by the river's flow.
#
# The shape and structure of a river's bank can vary greatly depending on factors like the river's velocity, sediment load, and surrounding topography. In general, there are two main types of banks: active and passive.
#
# Active banks are those that are constantly being shaped and reshaped by the river's erosive and depositional forces. These banks often have a steep slope, with a high rate of erosion on the upstream side and deposition on the downstream side. Active banks can be found in rivers with high velocities, such as rapids or whitewater sections.
#
# Passive banks, on the other hand, are those that are relatively stable and less affected by the river's erosive forces. These banks often have a gentler slope and may be composed of more resistant materials like bedrock or hard soil. Passive banks can be found in rivers with lower velocities, such as calm stretches or oxbow lakes.
#
# The bank also plays an important role in shaping the river's morphology, including its meanders, oxbow lakes, and floodplains. The interaction between the river and its bank can lead to the formation of unique landforms, such as point bars, levees, and floodplain terraces.
#
# In summary, the bank is a dynamic and complex feature that interacts with the river's flow to shape its course and character over time.
# --------------------------------------------------

# %% [markdown]
# ## Techniques for Writing Clearer Prompts

# %%
def compare_prompt_clarity(original_prompt, improved_prompt):
    """
    Compare the responses to an original prompt and an improved, clearer version.
    
    Args:
    original_prompt (str): The original, potentially unclear prompt
    improved_prompt (str): An improved, clearer version of the prompt
    
    Returns:
    tuple: Responses to the original and improved prompts
    """
    original_response = llm.invoke(original_prompt).content
    improved_response = llm.invoke(improved_prompt).content
    return original_response, improved_response

# Example usage
original_prompt = "How do I make it?"
improved_prompt = "Provide a step-by-step guide for making a classic margherita pizza, including ingredients and cooking instructions."

original_response, improved_response = compare_prompt_clarity(original_prompt, improved_prompt)

print("Original Prompt Response:")
print(original_response)
print("\nImproved Prompt Response:")
print(improved_response)
# Out:
# Original Prompt Response:
# I'm happy to help, but I need a bit more information. You didn't specify what "it" is that you want to make. Could you please provide more context or clarify what you're trying to create? Is it a recipe, a craft project, a piece of art, or something else entirely? I'll do my best to assist you once I have a better understanding of what you're looking for.
#
# Improved Prompt Response:
# Here's a step-by-step guide to making a classic Margherita pizza:
#
# Ingredients:
#
# For the dough:
#
# * 1 cup warm water
# * 2 teaspoons active dry yeast
# * 3 tablespoons olive oil
# * 1 teaspoon salt
# * 4 cups all-purpose flour
#
# For the sauce:
#
# * 2 cups crushed San Marzano tomatoes (or other fresh, flavorful tomatoes)
# * 2 cloves garlic, minced
# * 1 tablespoon olive oil
# * Salt and pepper to taste
#
# For the toppings:
#
# * 8 ounces fresh mozzarella cheese, sliced into thin rounds
# * Fresh basil leaves
#
# Instructions:
#
# **Step 1: Make the Dough**
#
# 1. In a large mixing bowl, combine the warm water and yeast. Let it sit for 5-10 minutes until the yeast is activated and foamy.
# 2. Add the olive oil, salt, and 2 cups of flour to the bowl. Mix until a shaggy dough forms.
# 3. Gradually add the remaining 2 cups of flour, one cup at a time, until the dough becomes smooth and elastic. You may not need all of the remaining flour, so add it gradually and be prepared to stop adding flour when the dough feels right.
# 4. Knead the dough on a floured surface for 5-10 minutes until it becomes smooth and elastic.
# 5. Place the dough in a lightly oiled bowl, cover it with plastic wrap, and let it rise in a warm place for 1-2 hours until it has doubled in size.
#
# **Step 2: Prepare the Sauce**
#
# 1. In a blender or food processor, combine the crushed tomatoes, garlic, olive oil, salt, and pepper. Blend until smooth.
# 2. Taste and adjust the seasoning as needed.
#
# **Step 3: Shape the Dough**
#
# 1. Preheat your oven to 500°F (260°C) with a baking stone or baking sheet inside. If you don't have a baking stone, you can use a regular oven rack.
# 2. Punch down the dough and divide it into 2-4 equal portions, depending on the size of pizza you want to make.
# 3. Roll out each portion of dough into a thin circle, about 12 inches in diameter.
#
# **Step 4: Assemble the Pizza**
#
# 1. Place the dough on a piece of parchment paper or a lightly floured pizza peel if you have one.
# 2. Spread a thin layer of sauce over the dough, leaving a small border around the edges.
# 3. Arrange the sliced mozzarella cheese over the sauce.
# 4. Sprinkle a few fresh basil leaves over the cheese.
#
# **Step 5: Bake the Pizza**
#
# 1. Slide the parchment paper or pizza peel onto the preheated baking stone or baking sheet.
# 2. Bake the pizza for 10-12 minutes until the crust is golden brown and the cheese is melted and bubbly.
# 3. Remove the pizza from the oven and let it cool for a few minutes before slicing and serving.
#
# Tips:
#
# * Use high-quality ingredients, such as San Marzano tomatoes and fresh mozzarella cheese, to get the best flavor out of your Margherita pizza.
# * Make sure the dough is at room temperature before shaping it, as this will help it rise evenly.
# * Don't overload the pizza with toppings, as this can make the crust soggy. Keep it simple with just a few ingredients!
# * If you don't have a baking stone or baking sheet, you can use a regular oven rack to bake the pizza.
#
# Enjoy your delicious homemade Margherita pizza!

# %% [markdown]
# ## Structured Prompts for Clarity

# %%
structured_prompt = PromptTemplate(
    input_variables=["topic", "aspects", "tone"],
    template="""Provide an analysis of {topic} considering the following aspects:
    1. {{aspects[0]}}
    2. {{aspects[1]}}
    3. {{aspects[2]}}
    
    Present the analysis in a {tone} tone.
    """
)

# Example usage
input_variables = {
    "topic": "the impact of social media on society",
    "aspects": ["communication patterns", "mental health", "information spread"],
    "tone": "balanced and objective"
}

chain = structured_prompt | llm
response = chain.invoke(input_variables).content
print(response)
# Out:
# Based on available research and data, here's an analysis of the impact of social media on society across three key aspects:
#
# **Aspect 1: Social Connections and Community Building**
#
# Social media has revolutionized the way people connect with each other. Platforms like Facebook, Instagram, and Twitter have enabled users to maintain relationships with friends and family who live far away, as well as connect with new people who share similar interests. This has led to a sense of community and belonging among social media users.
#
# On the positive side, social media has:
#
# * Enabled people to stay in touch with loved ones who are geographically distant
# * Provided opportunities for people to connect with others who share similar interests or passions
# * Facilitated the growth of online communities around shared causes or hobbies
#
# However, on the negative side, excessive social media use can lead to feelings of loneliness and isolation, as well as decreased face-to-face interaction skills.
#
# **Aspect 2: Mental Health and Wellbeing**
#
# Social media has been linked to both positive and negative effects on mental health. On the positive side, social media can:
#
# * Provide a sense of connection and community for people who are isolated or have difficulty forming relationships in person
# * Offer access to mental health resources and support groups
# * Provide an outlet for self-expression and creativity
#
# On the negative side, excessive social media use has been linked to increased symptoms of depression, anxiety, and loneliness. Cyberbullying, online harassment, and the constant stream of curated and manipulated content can also take a toll on mental wellbeing.
#
# **Aspect 3: Information Dissemination and Social Change**
#
# Social media has transformed the way information is disseminated and consumed. Platforms like Twitter, Facebook, and Instagram have enabled users to share news, opinions, and perspectives with a global audience.
#
# On the positive side, social media has:
#
# * Provided a powerful tool for social activism and mobilization
# * Enabled people to access information and resources that may not be available through traditional channels
# * Facilitated the growth of online movements and campaigns around social justice issues
#
# However, on the negative side, social media can also spread misinformation, propaganda, and hate speech. The algorithm-driven nature of many platforms can create "filter bubbles" that reinforce existing biases and limit exposure to diverse perspectives.
#
# In conclusion, social media has had a profound impact on society, with both positive and negative effects across various aspects. While it has enabled new forms of connection, community building, and information dissemination, it also poses challenges related to mental health, wellbeing, and the spread of misinformation. As social media continues to evolve, it is essential to acknowledge these complexities and strive for a more nuanced understanding of its role in shaping our lives and society.

# %% [markdown]
# ## Improving Prompt Clarity

# %%
unclear_prompts = [
    "What's the difference?",
    "How does it work?",
    "Why is it important?"
]

def improve_prompt_clarity(unclear_prompt):
    """
    Improve the clarity of a given prompt.
    
    Args:
    unclear_prompt (str): The original unclear prompt
    
    Returns:
    str: An improved, clearer version of the prompt
    """
    improvement_prompt = f"The following prompt is unclear: '{unclear_prompt}'. Please provide a clearer, more specific version of this prompt. output just the improved prompt and nothing else." 
    return llm.invoke(improvement_prompt).content

for prompt in unclear_prompts:
    improved_prompt = improve_prompt_clarity(prompt)
    print(f"Original: {prompt}")
    print(f"Improved: {improved_prompt}")
    print("-" * 50)
# Out:
# Original: What's the difference?
# Improved: What are you comparing or contrasting in two things, and what would you like to know about their differences?
# --------------------------------------------------
# Original: How does it work?
# Improved: What is the underlying mechanism or technology behind [specific system, process, or phenomenon]?
# --------------------------------------------------
# Original: Why is it important?
# Improved: What are the specific benefits or consequences of [specific topic or action]?
# --------------------------------------------------

# %% [markdown]
# # Prompt Length and Complex management

# %%
# Detailed prompt
detailed_prompt = PromptTemplate(
    input_variables=["topic"],
    template="""Please provide a comprehensive explanation of {topic}. Include its definition, 
    historical context, key components, practical applications, and any relevant examples. 
    Also, discuss any controversies or debates surrounding the topic, and mention potential 
    future developments or trends."""
)

# Concise prompt
concise_prompt = PromptTemplate(
    input_variables=["topic"],
    template="Briefly explain {topic} and its main importance."
)

topic = "artificial intelligence"

print("Detailed response:")
print(llm.invoke(detailed_prompt.format(topic=topic)).content)

print("\nConcise response:")
print(llm.invoke(concise_prompt.format(topic=topic)).content)
# Out:
# Detailed response:
# Artificial Intelligence (AI) is a broad field of computer science that focuses on creating intelligent machines capable of performing tasks that typically require human intelligence, such as learning, problem-solving, decision-making, and perception.
#
# **Definition:**
#
# Artificial Intelligence refers to the development of computer systems that can perform tasks that would normally require human intelligence, such as:
#
# 1. Learning: AI systems can learn from data and improve their performance over time.
# 2. Problem-solving: AI systems can solve complex problems by analyzing data and making decisions.
# 3. Perception: AI systems can interpret and understand data from sensors and other sources.
# 4. Reasoning: AI systems can draw conclusions based on the information they have been trained on.
#
# **Historical Context:**
#
# The concept of Artificial Intelligence dates back to the 1950s, when computer scientists like Alan Turing, Marvin Minsky, and John McCarthy began exploring the possibility of creating intelligent machines. The term "Artificial Intelligence" was coined in 1956 by John McCarthy, who organized the first AI conference at Dartmouth College.
#
# In the 1960s and 1970s, AI research focused on rule-based systems, expert systems, and machine learning. However, progress was slow due to the limitations of computing power and data availability.
#
# The 1980s saw a resurgence in AI research, with the development of neural networks and the introduction of the first commercial AI products. The 1990s and 2000s saw significant advancements in machine learning, natural language processing, and computer vision.
#
# **Key Components:**
#
# 1. **Machine Learning:** A subset of AI that enables machines to learn from data without being explicitly programmed.
# 2. **Deep Learning:** A type of machine learning that uses neural networks with multiple layers to analyze complex data.
# 3. **Natural Language Processing (NLP):** The ability of computers to understand, generate, and process human language.
# 4. **Computer Vision:** The ability of computers to interpret and understand visual data from images and videos.
#
# **Practical Applications:**
#
# 1. **Virtual Assistants:** AI-powered virtual assistants like Siri, Alexa, and Google Assistant can perform tasks such as scheduling appointments, setting reminders, and providing information on demand.
# 2. **Image Recognition:** AI-powered image recognition systems can identify objects, people, and patterns in images, with applications in self-driving cars, surveillance, and healthcare.
# 3. **Chatbots:** AI-powered chatbots can provide customer support, answer frequently asked questions, and engage in conversations with users.
# 4. **Predictive Maintenance:** AI-powered predictive maintenance systems can analyze sensor data to predict equipment failures and schedule maintenance.
#
# **Examples:**
#
# 1. **Google's AlphaGo:** A computer program that defeated a human world champion in Go, demonstrating the power of deep learning and machine learning.
# 2. **Amazon's Alexa:** A virtual assistant that uses NLP and machine learning to understand voice commands and perform tasks.
# 3. **Self-Driving Cars:** Companies like Waymo and Tesla are using AI-powered computer vision and machine learning to develop self-driving cars.
#
# **Controversies and Debates:**
#
# 1. **Job Displacement:** The increasing use of AI in industries may lead to job displacement, particularly for jobs that involve repetitive or routine tasks.
# 2. **Bias and Fairness:** AI systems can perpetuate biases and discrimination if they are trained on biased data or designed with a particular worldview.
# 3. **Ethics and Accountability:** As AI becomes more pervasive, there is growing concern about accountability and ethics in AI decision-making.
# 4. **Security Risks:** AI-powered systems can be vulnerable to cyber attacks and data breaches, highlighting the need for robust security measures.
#
# **Future Developments and Trends:**
#
# 1. **Explainable AI (XAI):** The development of XAI aims to provide insights into how AI systems make decisions, increasing transparency and trust.
# 2. **Edge AI:** The growing use of edge computing and IoT devices is enabling AI applications in real-time, reducing latency and improving performance.
# 3. **Human-AI Collaboration:** Researchers are exploring ways to enable humans and AI systems to collaborate more effectively, leading to improved productivity and decision-making.
# 4. **Quantum AI:** The integration of quantum computing with AI has the potential to revolutionize fields like optimization, simulation, and machine learning.
#
# In conclusion, Artificial Intelligence is a rapidly evolving field that has transformed industries and revolutionized the way we live and work. As AI continues to advance, it's essential to address the controversies and debates surrounding its development and deployment, while harnessing its potential to create a more intelligent, efficient, and equitable future.
#
# Concise response:
# Artificial Intelligence (AI) refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, decision-making, and perception.
#
# The main importance of AI lies in its ability to:
#
# 1. **Improve efficiency**: Automate repetitive and mundane tasks, freeing up time for more strategic and creative work.
# 2. **Enhance accuracy**: Reduce errors and improve precision in various industries, such as healthcare, finance, and transportation.
# 3. **Increase productivity**: Enable machines to learn from data and make decisions autonomously, leading to increased productivity and competitiveness.
# 4. **Drive innovation**: Facilitate the development of new products, services, and business models that can transform industries and improve people's lives.
#
# Overall, AI has the potential to revolutionize various aspects of our lives, from healthcare and education to transportation and entertainment, making it a crucial technology for the future.

# %% [markdown]
# ## Analysis of Prompt Balance

# %%
analysis_prompt = PromptTemplate(
    input_variables=["topic", "detailed_response", "concise_response"],
    template="""Compare the following two responses on {topic}:

Detailed response:
{detailed_response}

Concise response:
{concise_response}

Analyze the differences in terms of:
1. Information coverage
2. Clarity and focus
3. Potential use cases for each type of response

Then, suggest strategies for balancing detail and conciseness in prompts."""
)

detailed_response = llm.invoke(detailed_prompt.format(topic=topic)).content
concise_response = llm.invoke(concise_prompt.format(topic=topic)).content

analysis = llm.invoke(analysis_prompt.format(
    topic=topic,
    detailed_response=detailed_response,
    concise_response=concise_response
)).content

print(analysis)
# Out:
# **Differences in Response:**
#
# 1. **Information Coverage:** The detailed response provides a comprehensive overview of AI, covering its definition, historical context, key components, practical applications, examples, controversies, and future developments. In contrast, the concise response focuses on the main importance of AI, highlighting its ability to improve efficiency, enhance accuracy, increase productivity, and drive innovation.
# 2. **Clarity and Focus:** The detailed response is more structured and organized, with clear headings and subheadings that guide the reader through the content. The concise response is more straightforward and to the point, using simpler language and shorter sentences to convey the main ideas.
# 3. **Potential Use Cases for Each Type of Response:**
# 	* Detailed Response:
# 		+ Suitable for academic or research purposes, where a comprehensive overview is necessary.
# 		+ Useful for professionals or experts in AI who need to understand the nuances of the field.
# 		+ May be overwhelming for non-experts or those looking for a brief introduction to AI.
# 	* Concise Response:
# 		+ Ideal for general audiences or those seeking a quick understanding of AI's main benefits and applications.
# 		+ Suitable for marketing materials, social media posts, or other contexts where brevity is essential.
# 		+ May not provide enough depth or context for advanced users or professionals.
#
# **Strategies for Balancing Detail and Conciseness:**
#
# 1. **Define the Purpose:** Clearly determine the purpose of the response and the audience it will be addressed to. This will help you decide how much detail to include and what level of complexity is necessary.
# 2. **Use Headings and Subheadings:** Organize your content using headings and subheadings to guide the reader through the information and make it easier to scan.
# 3. **Prioritize Key Points:** Focus on the most important information and key points, and provide supporting details as needed.
# 4. **Use Simple Language:** Avoid using technical jargon or overly complex terminology that may confuse non-experts.
# 5. **Consider the Audience:** Tailor your response to the audience's level of expertise and knowledge. Use simpler language for general audiences and more technical terms for professionals.
# 6. **Use Visual Aids:** Incorporate images, diagrams, or infographics to help illustrate key concepts and make the content more engaging.
# 7. **Edit and Refine:** Review your response carefully and refine it as needed to ensure that it is clear, concise, and effective in communicating the intended message.
#
# By following these strategies, you can create responses that balance detail and conciseness, making them suitable for a wide range of audiences and purposes.

# %% [markdown]
# ## Handling Long Context

# %% [markdown]
# ### Chunking

# %%
# [A long passage about artificial intelligence, its history, applications, and future prospects...]
from langchain_text_splitters import RecursiveCharacterTextSplitter
#from langchain.chains.summarize import load_summarize_chain


long_text = """
Artificial intelligence (AI) is a branch of computer science that aims to create intelligent machines that can simulate human cognitive processes.
The field of AI has a rich history dating back to the 1950s, with key milestones such as the development of the first neural networks and expert systems.
AI encompasses a wide range of subfields, including machine learning, natural language processing, computer vision, and robotics.
Practical applications of AI include speech recognition, image classification, autonomous vehicles, and medical diagnosis.
AI has the potential to revolutionize many industries, from healthcare and finance to transportation and entertainment.
However, there are ongoing debates and controversies surrounding AI, such as concerns about job displacement, bias in algorithms, and the ethical implications of autonomous systems.
Looking ahead, the future of AI holds promise for advancements in areas like explainable AI, AI ethics, and human-AI collaboration. 
The intersection of AI with other technologies like blockchain, quantum computing, and biotechnology will likely shape the future of the field.
But as AI continues to evolve, it is essential to consider the societal impact and ethical implications of these technologies.
One of the key challenges for AI researchers and developers is to strike a balance between innovation and responsibility, ensuring that AI benefits society as 
a whole while minimizing potential risks.
If managed effectively, AI has the potential to transform our world in ways we can only begin to imagine.
Though the future of AI is uncertain, one thing is clear: the impact of artificial intelligence will be profound and far-reaching.
"""

# Initialize the text splitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    length_function=len
)

# Split the text into chunks
chunks = text_splitter.split_text(long_text)

print(f"Number of chunks: {len(chunks)}")
print(f"First chunk: {chunks[0][:200]}...")
# Out:
# Number of chunks: 2
# First chunk: Artificial intelligence (AI) is a branch of computer science that aims to create intelligent machines that can simulate human cognitive processes.
# The field of AI has a rich history dating back to the...

# %% [markdown]
# ### Summarization

# %%
# Convert to Document objects
doc_chunks = [Document(page_content=chunk) for chunk in chunks]


map_prompt = ChatPromptTemplate.from_template(
    "Write a concise summary of the following text:\n\n{text}"
)

map_chain = map_prompt | llm


reduce_prompt = ChatPromptTemplate.from_template(
    """
The following are partial summaries:

{text}

Create a final, well-structured, concise summary.
"""
)

reduce_chain = reduce_prompt | llm



mapped_summaries = []

for doc in doc_chunks:
    result = map_chain.invoke({"text": doc.page_content})
    mapped_summaries.append(result.content)


final_summary = reduce_chain.invoke({
    "text": "\n\n".join(mapped_summaries)
})



print("Summary:\n")
print(final_summary.content)
# Out:
# Summary:
#
# Here is a final, well-structured, concise summary:
#
# Artificial intelligence (AI) aims to create intelligent machines that simulate human cognitive processes, with a rich history dating back to the 1950s. While AI has numerous practical applications across industries, it also raises concerns about job displacement, bias, and ethics. As AI continues to evolve, its future holds promise for advancements in explainable AI, ethics, and collaboration with humans. However, it is essential to consider societal impact and ethical implications to balance innovation with responsibility, ensuring that AI benefits society while minimizing risks. The potential impact of AI on the world will be profound and far-reaching, requiring careful consideration and responsible development to maximize its benefits.

# %% [markdown]
# ### Iterative Processing

# %%
def iterative_analysis(text, steps):
    """
    Perform iterative analysis on a given text.
    
    Args:
    text (str): The text to analyze.
    steps (list): List of analysis steps to perform.
    
    Returns:
    str: The final analysis result.
    """
    result = text
    for step in steps:
        prompt = PromptTemplate(
            input_variables=["text"],
            template=f"Analyze the following text. {step}\n\nText: {{text}}\n\nAnalysis:"
        )
        result = llm.invoke(prompt.format(text=result)).content
    return result

analysis_steps = [
    "Identify the main topics discussed.",
    "Summarize the key points for each topic.",
    "Provide a brief conclusion based on the analysis."
]

final_analysis = iterative_analysis(long_text, analysis_steps)
print("Final Analysis:")
print(final_analysis)
# Out:
# Final Analysis:
# Based on the analysis of the provided text, it appears to be an outline or a framework for discussing various aspects of Artificial Intelligence (AI). The structure suggests that the text is intended to provide a comprehensive overview of AI, covering its definition, history, applications, challenges, future developments, and societal impact.
#
# The text highlights the importance of considering both the benefits and risks associated with AI, emphasizing the need for responsible development, deployment, and use of this technology. It also touches on various areas of research and development that are likely to shape the future of AI.
#
# Some key themes that emerge from the analysis include:
#
# 1. The complexity and multifaceted nature of AI, requiring consideration of both technical and societal implications.
# 2. The need for responsible innovation and deployment of AI, balancing benefits with potential risks and negative consequences.
# 3. The importance of ongoing research and development in areas like explainable AI, AI ethics, and human-AI collaboration to further enhance the capabilities and benefits of AI.
#
# Overall, the text appears to be a comprehensive framework for understanding the current state and future directions of AI, highlighting both its potential benefits and challenges.

# %%
tips_prompt = """
Based on the examples and strategies we've explored for managing prompt length and complexity, 
provide a list of 5 practical tips for developers working with large language models. 
Each tip should be concise and actionable.
"""

tips = llm.invoke(tips_prompt).content
print(tips)
