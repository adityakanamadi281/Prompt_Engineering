# %%
import requests
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

from openai import OpenAI

# %%
requests.get("http://localhost:11434").content

OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

model_name="llama3.2"

# %%
from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama
#from langchain.memory import ConversationBufferMemory
from langchain_core.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_classic.chains import ConversationChain
from langchain_classic.memory import ConversationBufferMemory

# %%
# Initialize the Ollama model
llm = ChatOllama(
    model=model_name,   # change to mistral / qwen2.5 if you want
    temperature=0
)

# %% [markdown]
# ## Generating Multiple Reasoning Paths

# %%
def generate_multiple_paths(problem, num_paths=3):
    """
    Generate multiple reasoning paths for a given problem.
    
    Args:
    problem (str): The problem statement.
    num_paths (int): Number of reasoning paths to generate.
    
    Returns:
    list: A list of generated reasoning paths.
    """
    prompt_template = PromptTemplate(
        input_variables=["problem", "path_number"],
        template="""Solve the following problem using a unique approach. This is reasoning path {path_number}.
        Problem: {problem}
        Reasoning path {path_number}:"""
    )

    paths = []
    for i in range(num_paths):
        chain = prompt_template | llm
        response = chain.invoke({"problem": problem, "path_number": i+1}).content
        paths.append(response)
    
    return paths

# %%
problem = "A ball is thrown upwards with an initial velocity of 20 m/s. How high will it go?"
paths = generate_multiple_paths(problem)

for i, path in enumerate(paths, 1):
    print(f"Path {i}:\n{path}\n")
# Out:
# Path 1:
# This problem can be solved by considering the motion of the ball as a projectile under the influence of gravity. Since the ball is thrown upwards, its vertical component of velocity decreases due to gravity until it reaches its maximum height.
#
# Let's consider the following steps:
#
# 1. The initial upward velocity of 20 m/s will decrease at a rate of 9.8 m/s^2 (acceleration due to gravity) until it becomes zero.
# 2. At this point, the ball has reached its maximum height and momentarily comes to rest.
# 3. From this point onwards, the ball starts falling downwards under the influence of gravity.
#
# To find the maximum height, we can use the following equation:
#
# v^2 = u^2 + 2as
#
# where:
# - v is the final velocity (0 m/s at the maximum height)
# - u is the initial velocity (20 m/s upwards)
# - a is the acceleration due to gravity (-9.8 m/s^2, negative because it's acting downwards)
# - s is the displacement (height) we want to find
#
# Rearranging the equation to solve for s, we get:
#
# s = v^2 / 2a
# = 0^2 / 2(-9.8)
# = 0 / -19.6
# = 0 + 20^2 / 2(9.8)
#
# However, this approach is not correct because it assumes that the ball will come to rest at its maximum height and then start falling downwards.
#
# A better approach would be to use the equation of motion under gravity:
#
# s = ut - (1/2)at^2
#
# where:
# - s is the displacement (height)
# - u is the initial velocity (20 m/s upwards)
# - t is time
# - a is the acceleration due to gravity (-9.8 m/s^2)
#
# Since we want to find the maximum height, we need to find the time at which the ball reaches its maximum height. This occurs when the vertical component of velocity becomes zero:
#
# u - gt = 0
#
# where:
# - u is the initial upward velocity (20 m/s)
# - g is the acceleration due to gravity (-9.8 m/s^2)
# - t is time
#
# Rearranging the equation to solve for t, we get:
#
# t = u / g
# = 20 / -9.8
# = -2.04 s
#
# The negative sign indicates that the ball has been moving upwards for this amount of time.
#
# Now, we can plug this value of t into the equation of motion under gravity to find the maximum height:
#
# s = ut - (1/2)at^2
# = 20(-2.04) - (1/2)(-9.8)(-2.04)^2
# = -40.8 - 20.4
# = -61.2 m
#
# However, this is the displacement from the starting point of the ball's motion. To find the maximum height above the ground, we need to add the initial upward velocity multiplied by time:
#
# s = ut + s0
#
# where:
# - s is the displacement (height)
# - u is the initial upward velocity (20 m/s)
# - t is time
# - s0 is the initial height (which we don't know)
#
# Since the ball was thrown upwards, its initial height above the ground is zero. Therefore:
#
# s = ut
# = 20(-2.04)
# = -40.8 m
#
# The negative sign indicates that the maximum height is below the starting point of the ball's motion.
#
# To find the actual maximum height above the ground, we need to add the absolute value of this displacement to the initial height (which is zero):
#
# s = |ut|
# = |-40.8|
# = 40.8 m
#
# Therefore, the ball will reach a maximum height of approximately 40.8 meters above the starting point of its motion.
#
# However, if you want to find the maximum height above the ground, we need more information about the initial height or the position of the observer.
#
# Path 2:
# This problem can be solved by considering the motion of the ball as a continuous process, rather than in discrete steps. We can model the motion using the equation for uniformly accelerated motion:
#
# s(t) = s0 + v0t - (1/2)gt^2
#
# where:
# - s(t) is the height at time t
# - s0 is the initial height (which we assume to be 0, since the ball is thrown upwards from the ground)
# - v0 is the initial velocity (20 m/s in this case)
# - g is the acceleration due to gravity (-9.8 m/s^2)
#
# Since the ball is thrown upwards, the acceleration due to gravity will eventually cause it to slow down and then come back down. We can find the maximum height by finding when the velocity of the ball becomes zero.
#
# The velocity at time t is given by:
#
# v(t) = v0 - gt
#
# We want to find when v(t) = 0, so we set up the equation:
#
# 20 - 9.8t = 0
#
# Solving for t, we get:
#
# t = 20 / 9.8 ≈ 2.04 seconds
#
# Now that we have found the time at which the ball reaches its maximum height, we can plug this value back into the equation for s(t) to find the maximum height:
#
# s(2.04) = 0 + 20(2.04) - (1/2)(-9.8)(2.04)^2
# = 40.8 + 20.4
# ≈ 61.2 meters
#
# Therefore, the ball will reach a maximum height of approximately 61.2 meters.
#
# Path 3:
# This problem can be solved by considering the motion of the ball as a continuous process, rather than in discrete steps. We can model the motion using the equation for uniformly accelerated motion:
#
# s(t) = s0 + v0t - (1/2)gt^2
#
# where:
# - s(t) is the height at time t
# - s0 is the initial height (which we assume to be 0, since the ball is thrown upwards from the ground)
# - v0 is the initial velocity (20 m/s in this case)
# - g is the acceleration due to gravity (-9.8 m/s^2)
#
# We can rearrange the equation to solve for t:
#
# t = (v0 + sqrt(v0^2 + 2gs0)) / g
#
# Substituting the values, we get:
#
# t = (20 + sqrt(20^2 + 2(-9.8)(0))) / (-9.8)
# t ≈ 1.02 seconds
#
# Now that we have the time it takes for the ball to reach its maximum height, we can find the maximum height itself by substituting t into the original equation:
#
# s(t) = s0 + v0t - (1/2)gt^2
# = 0 + 20(1.02) - (1/2)(-9.8)(1.02)^2
# ≈ 20.4 meters
#
# Therefore, the ball will reach a height of approximately 20.4 meters above the ground.
#
# This approach allows us to model the motion of the ball as a continuous process, which can be more intuitive and easier to work with than discrete step-by-step calculations.

# %% [markdown]
# ## Aggregating Results

# %%
def aggregate_results(paths):
    """
    Aggregate results from multiple reasoning paths.
    
    Args:
    paths (list): List of reasoning paths.
    
    Returns:
    str: The most consistent answer.
    """
    prompt_template = PromptTemplate(
        input_variables=["paths"],
        template="""Analyze the following reasoning paths and determine the most consistent answer. If there are discrepancies,
        explain why and provide the most likely correct answer.
        Reasoning paths:
        {paths}
        
        Most consistent answer:"""
    )

    chain = prompt_template | llm
    response = chain.invoke({"paths": "\n".join(paths)}).content
    return response

# %%
aggregated_result = aggregate_results(paths)
print("Aggregated Result:\n", aggregated_result)
# Out:
# Aggregated Result:
#  The most consistent answer is:
#
# s(t) = s0 + v0t - (1/2)gt^2
# = 0 + 20(1.02) - (1/2)(-9.8)(1.02)^2
# ≈ 20.4 meters
#
# This approach allows us to model the motion of the ball as a continuous process, which can be more intuitive and easier to work with than discrete step-by-step calculations.
#
# The other approaches have discrepancies:
#
# * The first approach assumes that the ball comes to rest at its maximum height and then starts falling downwards, which is not accurate.
# * The second approach uses the equation v(t) = v0 - gt to find when the velocity becomes zero, but it does not take into account the initial upward velocity correctly.
#
# The third approach is more consistent because it models the motion of the ball as a continuous process and takes into account the initial upward velocity correctly. It also provides a clear and intuitive solution for finding the maximum height above the ground.

# %% [markdown]
# ## Self-Consistency Check

# %%
def self_consistency_check(problem, aggregated_result):
    """
    Perform a self-consistency check on the aggregated result.
    
    Args:
    problem (str): The original problem statement.
    aggregated_result (str): The aggregated result to check.
    
    Returns:
    str: An evaluation of the result's consistency and reliability.
    """
    prompt_template = PromptTemplate(
        input_variables=["problem", "result"],
        template="""Evaluate the consistency and reliability of the following result for the given problem.
        Problem: {problem}
        Result: {result}
        
        Evaluation (consider factors like logical consistency, adherence to known facts, and potential biases):"""
    )

    chain = prompt_template | llm
    response = chain.invoke({"problem": problem, "result": aggregated_result}).content
    return response

# %%
consistency_evaluation = self_consistency_check(problem, aggregated_result)
print("Self-Consistency Evaluation:\n", consistency_evaluation)
# Out:
# Self-Consistency Evaluation:
#  The evaluation of the result's consistency and reliability is as follows:
#
# 1.  **Logical Consistency:** The approach used in the result is based on the equation for uniformly accelerated motion under gravity, which is a fundamental concept in physics. The use of this equation to model the ball's motion as a continuous process is logical and consistent with established principles.
#
# 2.  **Adherence to Known Facts:** The result adheres to known facts about projectile motion under gravity. It correctly accounts for the initial upward velocity, acceleration due to gravity, and the resulting maximum height reached by the ball.
#
# 3.  **Potential Biases:** There are no apparent biases in the approach used in the result. However, it's worth noting that the assumption of a flat, horizontal surface might not be accurate in all scenarios (e.g., on an inclined plane or in a real-world environment with air resistance). Nonetheless, for simplicity and to maintain consistency with basic physics principles, this assumption is reasonable.
#
# 4.  **Accuracy:** The result provides an approximate value of approximately 20.4 meters as the maximum height reached by the ball. This value aligns well with known results from similar problems in physics education, suggesting that it's a reliable estimate.
#
# 5.  **Intuitive Understanding:** The approach used in the result is indeed more intuitive and easier to work with than discrete step-by-step calculations for modeling continuous processes like projectile motion under gravity. It provides a clear and straightforward method for finding the maximum height above the ground.
#
# In conclusion, the result's consistency and reliability are high due to its adherence to established physics principles, logical coherence, and accuracy in estimating the maximum height reached by the ball.

# %% [markdown]
# ## Applying different Problem type

# %%
def solve_problem(problem):
    """
    Solve a problem using multiple reasoning paths, aggregation, and self-consistency check.
    
    Args:
    problem (str): The problem statement.
    
    Returns:
    tuple: (aggregated_result, consistency_evaluation)
    """
    paths = generate_multiple_paths(problem)
    aggregated_result = aggregate_results(paths)
    consistency_evaluation = self_consistency_check(problem, aggregated_result)
    return aggregated_result, consistency_evaluation

# Example problems
problems = [
    "What is the capital of France?",
    "Explain the concept of supply and demand in economics.",
    "If a train travels at 60 km/h, how long will it take to cover 180 km?"
]

for problem in problems:
    print(f"Problem: {problem}")
    result, evaluation = solve_problem(problem)
    print("Aggregated Result:\n", result)
    print("\nConsistency Evaluation:\n", evaluation)
    print("\n" + "-"*50 + "\n")
# Out:
# Problem: What is the capital of France?
# Aggregated Result:
#  After analyzing all three reasoning paths, I can conclude that the most consistent answer is:
#
# **Paris is likely to be the capital of France.**
#
# Here's why:
#
# 1. **Consistency across paths**: All three paths lead to the conclusion that Paris is a significant urban center in France, culturally influential, and historically important.
# 2. **Lack of contradictory evidence**: None of the reasoning paths present any contradictory information that would suggest another city in France is the capital.
# 3. **Use of observation and pattern recognition**: Each path uses observation and pattern recognition to gather information about the concept of "capital" and its relationship with France, which is a consistent approach.
#
# The only discrepancy between the three paths is the level of detail and specificity provided. Path 1 provides more general observations, while Paths 2 and 3 offer more specific examples and patterns. However, all three paths ultimately lead to the same conclusion: Paris is likely to be the capital of France.
#
# It's worth noting that the reasoning paths share a common thread in using observation and pattern recognition to arrive at an answer. This approach can be effective when combined with traditional knowledge or research, as seen in Path 1.
#
# Consistency Evaluation:
#  The result is generally consistent and reliable, but there are some areas that could be improved upon:
#
# Strengths:
#
# 1. The conclusion is based on a thorough analysis of three different reasoning paths, which demonstrates a systematic approach to problem-solving.
# 2. The use of observation and pattern recognition as a methodological framework is sound and effective in this context.
# 3. The acknowledgment of potential discrepancies between the paths (e.g., level of detail) shows an awareness of limitations and a willingness to consider alternative perspectives.
#
# Weaknesses:
#
# 1. **Lack of explicit evidence**: While the reasoning paths are consistent, there is no explicit evidence presented to support the conclusion that Paris is the capital of France. The result relies on inference and pattern recognition, which may not be sufficient to establish a definitive answer.
# 2. **Assumptions about "capital"**: The definition of "capital" is not explicitly stated or justified in the reasoning paths. This assumption could lead to potential biases or misunderstandings about what constitutes a capital city.
# 3. **Overemphasis on consistency**: While consistency across paths is important, it's equally crucial to consider alternative explanations and potential counterarguments. Failing to address these might lead to an overly simplistic conclusion.
# 4. **Lack of consideration for external knowledge**: The result relies heavily on observation and pattern recognition, but there may be external knowledge or research that contradicts the conclusion. For instance, some sources might argue that other cities in France (e.g., Lyon) have been considered capitals at various points in history.
#
# To improve the consistency and reliability of the result:
#
# 1. **Provide explicit evidence**: Include concrete data, statistics, or expert opinions to support the conclusion that Paris is the capital of France.
# 2. **Define "capital" explicitly**: Clearly articulate the definition of a capital city and justify it within the reasoning paths.
# 3. **Consider alternative explanations**: Address potential counterarguments and alternative perspectives on what constitutes a capital city.
# 4. **Integrate external knowledge**: Incorporate relevant research or expert opinions to strengthen the conclusion and demonstrate a more comprehensive understanding of the topic.
#
# By addressing these areas, the result can be made even more robust and reliable.
#
# --------------------------------------------------
#
# Problem: Explain the concept of supply and demand in economics.
# Aggregated Result:
#  After analyzing the three reasoning paths, I have identified some discrepancies and inconsistencies.
#
# 1. The first path uses a concert scenario to illustrate the concept of supply and demand, while the second path uses a music festival scenario with a different artist. While both scenarios are relatable and memorable, they differ in their context and application.
# 2. The third path takes an unconventional approach by using game theory to explain supply and demand. However, this approach is not as consistent as the first two paths, which use more traditional economic concepts and examples.
#
# Despite these discrepancies, I would argue that the most consistent answer lies in the first path. This is because it:
#
# 1. Uses a clear and concise example (the concert scenario) to illustrate the concept of supply and demand.
# 2. Provides a straightforward explanation of how markets work, balancing the quantity of a good or service that producers are willing to sell with the quantity that consumers are willing to buy.
# 3. Clearly defines the equilibrium price and quantity as the point where the market is in balance.
#
# While the second path uses a different scenario (the music festival) and highlights the dynamic interplay between supply and demand, it also introduces some inconsistencies, such as:
#
# 1. The artist's perspective on supply being limited by their own well-being, which may not be universally applicable.
# 2. The fan's perspective on demand being influenced by their desire for a premium experience, which may not accurately represent all consumers.
#
# The third path, while interesting and thought-provoking, is less consistent due to its use of game theory and the introduction of new concepts (e.g., Alice and Bob as players) that may not be immediately clear or relatable to non-economists.
#
# In conclusion, while there are some discrepancies between the three reasoning paths, I believe that the first path provides the most consistent answer to explaining supply and demand in economics.
#
# Consistency Evaluation:
#  The evaluation of the result is generally strong, but with some areas for improvement.
#
# Strengths:
#
# 1. The result clearly identifies discrepancies between the three reasoning paths and provides a clear explanation of why the first path is considered the most consistent.
# 2. The analysis highlights the importance of using relatable examples (concert scenario) to illustrate complex economic concepts (supply and demand).
# 3. The evaluation acknowledges potential inconsistencies in each path, demonstrating a nuanced understanding of the subject matter.
#
# Weaknesses:
#
# 1. The conclusion that the first path provides the most consistent answer may be subjective and influenced by personal preference or bias towards traditional economic explanations.
# 2. The evaluation does not provide a clear justification for why game theory is less consistent than traditional economic concepts. While it's true that game theory introduces new concepts, it can also provide a more nuanced understanding of complex market dynamics.
# 3. The result could benefit from more explicit consideration of potential biases, such as the assumption that all consumers are equally motivated by desire for a premium experience (music festival scenario).
# 4. The evaluation does not provide a clear recommendation for how to improve the consistency of the reasoning paths or address the identified discrepancies.
#
# Suggestions for improvement:
#
# 1. Consider multiple perspectives: Engage with counterarguments and alternative explanations to strengthen the evaluation.
# 2. Provide more explicit justification: Offer clear reasons why game theory is less consistent than traditional economic concepts, and explain how this affects the overall evaluation.
# 3. Address potential biases: Acknowledge and address potential biases in each reasoning path, such as the assumption that all consumers are equally motivated by desire for a premium experience.
# 4. Offer concrete recommendations: Provide suggestions for how to improve the consistency of the reasoning paths or address the identified discrepancies.
#
# Overall, the evaluation demonstrates a strong understanding of the subject matter and provides a clear analysis of the strengths and weaknesses of each reasoning path. With some refinement, it could become an even more robust and convincing argument.
#
# --------------------------------------------------
#
# Problem: If a train travels at 60 km/h, how long will it take to cover 180 km?
# Aggregated Result:
#  After analyzing all three reasoning paths, I conclude that the most consistent answer is:
#
# **Path A**
#
# The first path presents a classic problem-solving approach using counting and basic arithmetic. The explanation is straightforward, easy to follow, and uses simple language.
#
# In contrast, Path B introduces additional complexity with variables (x) and algebraic equations. While this approach may be more rigorous, it also relies on assumptions about the friend's perspective and the relationship between distance and time.
#
# Path C takes a creative approach by using visualization and spatial reasoning. However, this method is less intuitive than Path A and requires a different way of thinking about the problem.
#
# The most consistent answer is Path A because:
#
# 1. It uses simple language and basic arithmetic, making it accessible to a wider audience.
# 2. The explanation is straightforward and easy to follow, with no unnecessary assumptions or complex variables.
# 3. The solution relies on fundamental concepts of counting and time, which are well-established in mathematics.
#
# While the other paths present interesting approaches, they introduce additional complexity that may not be necessary for this particular problem. Path A provides a clear, concise, and intuitive solution that is most consistent with the original problem statement.
#
# Consistency Evaluation:
#  The evaluation of the result is well-structured and provides a clear analysis of each reasoning path. Here are some strengths and weaknesses of the evaluation:
#
# Strengths:
#
# 1. The evaluation acknowledges the limitations of each path and recognizes that Path A provides a more straightforward and intuitive solution.
# 2. It highlights the importance of simplicity, clarity, and adherence to fundamental concepts in mathematics.
# 3. The evaluation demonstrates an understanding of the problem statement and its requirements.
#
# Weaknesses:
#
# 1. The evaluation relies heavily on subjective judgments about the "consistency" of each path. While Path A is indeed more straightforward and intuitive, this assessment may be influenced by personal biases or preferences.
# 2. The evaluation does not provide a clear definition of what it means for an answer to be "consistent." Is it referring to mathematical consistency, logical coherence, or something else?
# 3. The evaluation assumes that the problem statement is well-defined and unambiguous. However, in real-world problems, there may be ambiguities or uncertainties that need to be addressed.
# 4. The evaluation does not consider potential errors or inaccuracies in Path A's solution. For example, the calculation of time based on distance and speed is a fundamental concept in physics, but it assumes a constant speed, which may not always be the case.
#
# To improve the evaluation, it would be helpful to:
#
# 1. Define what "consistency" means in this context and provide clear criteria for evaluating each path.
# 2. Consider potential biases or assumptions that may influence the evaluation.
# 3. Provide more detailed explanations of why Path A is considered the most consistent solution.
# 4. Acknowledge potential limitations or errors in Path A's solution.
#
# Overall, the evaluation provides a good starting point for assessing the consistency and reliability of the result. However, it would benefit from further refinement to ensure that the assessment is more objective and comprehensive.
#
# --------------------------------------------------

# %%
# Function to display model outputs
def display_output(output):
    """Display the model's output in a formatted manner."""
    print("Model Output:")
    print("-" * 40)
    print(output)
    print("-" * 40)
    print()

# %% [markdown]
# ## Setting Constraints for Model Outputs

# %%
constrained_prompt = PromptTemplate(
    input_variables=["product", "target_audience", "tone", "word_limit"],
    template="""Create a product description for {product} targeted at {target_audience}.
    Use a {tone} tone and keep it under {word_limit} words.
    The description should include:
    1. A catchy headline
    2. Three key features
    3. A call to action
    
    Product Description:
    """
)

# Generate the constrained output
input_variables = {
    "product": "smart water bottle",
    "target_audience": "health-conscious millennials",
    "tone": "casual and friendly",
    "word_limit": "75"
}

chain = constrained_prompt | llm
output = chain.invoke(input_variables).content
display_output(output)
# Out:
# Model Output:
# ----------------------------------------
# **Hydrate Your Way to Happiness**
#
# Stay on top of your game with our smart water bottle!
#
# Track your daily hydration goals with our built-in sensor
# Monitor your water intake and receive reminders to drink up
# Get access to personalized nutrition advice and healthy recipes via our mobile app
#
# Download the app now and start sipping your way to a healthier you!
# ----------------------------------------

# %% [markdown]
# ## Implementing Rule-based generation

# %%
job_posting_prompt = PromptTemplate(
    input_variables=["job_title", "company", "location", "experience"],
    template="""Create a job posting for a {job_title} position at {company} in {location}.
    The candidate should have {experience} years of experience.
    Follow these rules:
    1. Start with a brief company description (2 sentences)
    2. List 5 key responsibilities, each starting with an action verb
    3. List 5 required qualifications, each in a single sentence
    4. End with a standardized equal opportunity statement
    
    Format the output as follows:
    COMPANY: [Company Description]
    
    RESPONSIBILITIES:
    - [Responsibility 1]
    - [Responsibility 2]
    - [Responsibility 3]
    - [Responsibility 4]
    - [Responsibility 5]
    
    QUALIFICATIONS:
    - [Qualification 1]
    - [Qualification 2]
    - [Qualification 3]
    - [Qualification 4]
    - [Qualification 5]
    
    EEO: [Equal Opportunity Statement]
    """
)

# Generate the rule-based output
input_variables = {
    "job_title": "Senior Software Engineer",
    "company": "TechInnovate Solutions",
    "location": "San Francisco, CA",
    "experience": "5+"
}

chain = job_posting_prompt | llm
output = chain.invoke(input_variables).content
display_output(output)
# Out:
# Model Output:
# ----------------------------------------
# COMPANY: TechInnovate Solutions is a leading technology firm in San Francisco, CA, dedicated to delivering innovative software solutions to clients across various industries. With a strong focus on collaboration and customer satisfaction, we strive to be at the forefront of technological advancements.
#
# RESPONSIBILITIES:
# - Design and develop complex software systems that meet client requirements
# - Collaborate with cross-functional teams to identify and prioritize project needs
# - Implement automated testing and deployment scripts to ensure seamless system integration
# - Develop and maintain technical documentation to facilitate knowledge sharing within the team
# - Lead code reviews and mentor junior engineers to promote best practices
#
# QUALIFICATIONS:
# - Possess at least 5+ years of experience in software engineering, with a strong track record of delivering high-quality solutions
# - Hold a Bachelor's or Master's degree in Computer Science or a related field
# - Proficient in multiple programming languages, including Java, Python, and C++
# - Experience with Agile development methodologies and version control systems such as Git
# - Strong understanding of cloud computing platforms, including AWS or Azure
#
# EEO: TechInnovate Solutions is an equal opportunity employer committed to diversity and inclusion. We welcome applications from qualified candidates of all backgrounds and perspectives.
# ----------------------------------------

# %% [markdown]
# ## Structured Outputs

# %%
from pydantic import BaseModel

# %%
class JobPosting(BaseModel):
    company_description: str
    responsibilities: list[str]
    qualifications: list[str]
    eeo_statement: str



structured_llm = llm.with_structured_output(JobPosting)


prompt = ChatPromptTemplate.from_template("""
Create a job posting for a {job_title} position at {company} in {location}.
The candidate should have {experience} years of experience.

Follow these rules:
1. Company description → 2 sentences
2. 5 key responsibilities → action verbs
3. 5 qualifications → single sentence each
4. Equal opportunity statement at the end
""")



chain = prompt | structured_llm


input_data = {
    "job_title": "AI Engineer",
    "company": "TechNova",
    "location": "Bangalore",
    "experience": "3+"
}



result = chain.invoke(input_data)


print("\nPARSED OUTPUT:\n")

print("COMPANY DESCRIPTION:")
print(result.company_description, "\n")

print("RESPONSIBILITIES:")
for r in result.responsibilities:
    print("-", r)
print()

print("QUALIFICATIONS:")
for q in result.qualifications:
    print("-", q)
print()

print("EEO STATEMENT:")
print(result.eeo_statement)
# Out:
# PARSED OUTPUT:
#
# COMPANY DESCRIPTION:
# TechNova is a leading technology company that specializes in developing innovative AI and machine learning solutions for various industries. With a strong focus on research and development, we are committed to pushing the boundaries of what is possible with AI.
#
# RESPONSIBILITIES:
# - Design and develop intelligent systems using cutting-edge AI technologies
# - Collaborate with cross-functional teams to integrate AI models into existing applications
# - Develop and deploy machine learning algorithms for predictive analytics and data science projects
# - Conduct research and stay up-to-date with the latest advancements in AI and machine learning
# - Work closely with stakeholders to understand business requirements and deliver tailored AI solutions
#
# QUALIFICATIONS:
# - Bachelor's or Master's degree in Computer Science, Electrical Engineering, or related field
# - 3+ years of experience in AI engineering, software development, or a related field
# - Strong proficiency in programming languages such as Python, Java, or C++
# - Experience with deep learning frameworks and libraries like TensorFlow, PyTorch, or Keras
# - Certification in AI or machine learning is an added advantage
#
# EEO STATEMENT:
# TechNova is an equal opportunities employer. We welcome applications from diverse candidates and are committed to creating an inclusive work environment.

# %%
review_prompt = PromptTemplate(
    input_variables=["product", "rating", "pros", "cons", "word_limit"],
    template="""Write a product review for {product} with the following constraints:

1. The review should have a {rating}-star rating (out of 5)
2. Include exactly {pros} pros and {cons} cons
3. Use between 2 and 3 sentences for each pro and con
4. The entire review should be under {word_limit} words
5. End with a one-sentence recommendation

Format the review as follows:

Rating: [X] out of 5 stars

Pros:
1. [Pro 1]
2. [Pro 2]

Cons:
1. [Con 1]
2. [Con 2]

Recommendation: [One-sentence recommendation]
"""
)



input_data = {
    "product": "Smartphone X",
    "rating": "4",
    "pros": "3",
    "cons": "2",
    "word_limit": "200"
}


chain = review_prompt | llm



response = chain.invoke(input_data)



print(response.content)
# Out:
# Rating: 4 out of 5 stars
#
# Pros:
# 1. The Smartphone X has an impressive camera system, capable of capturing high-quality photos and videos even in low-light conditions. The advanced features such as portrait mode and bokeh effect are also a great addition to the camera app. Overall, the camera is one of the standout features of this device.
# 2. The phone's battery life is excellent, lasting up to 2 days with moderate usage. This is thanks to the efficient processor and power-saving features that help reduce battery drain. Whether you're using it for gaming or social media, the battery will keep going all day long.
# 3. The Smartphone X has a sleek and durable design, making it perfect for those who want a premium feel without breaking the bank. The phone's weight is also well-balanced, making it comfortable to hold and use.
#
# Cons:
# 1. The phone's storage capacity could be better, with only 128GB available. This may not be enough for users who need more space for their files and apps.
# 2. The fingerprint sensor can be slow at times, requiring multiple attempts to unlock the device.
#
# Recommendation: Overall, the Smartphone X is a great choice for those looking for a high-quality smartphone without breaking the bank, but it's worth considering the storage capacity before making a purchase.

# %% [markdown]
# # Role Prompting

# %%
tech_writer_prompt = PromptTemplate(
    input_variables=["topic"],
    template="""You are a technical writer specializing in creating clear and concise documentation for software products.
    Your task is to write a brief explanation of {topic} for a user manual.
    Please provide a 2-3 sentence explanation that is easy for non-technical users to understand."""
)

chain = tech_writer_prompt | llm
response = chain.invoke({"topic": "cloud computing"})
print(response.content)
# Out:
# Here's a possible explanation:
#
# "Cloud computing is a way to store, manage, and access data and applications over the internet, rather than on your own computer or device. This means you can use software and access files from anywhere with an internet connection, without having to worry about storing them on your local hard drive. Think of it like renting a virtual storage space that's accessible from anywhere, at any time."

# %%
financial_advisor_prompt = PromptTemplate(
    input_variables=["client_situation"],
    template="""You are a seasoned financial advisor with over 20 years of experience in personal finance, investment strategies, and retirement planning.
    You have a track record of helping clients from diverse backgrounds achieve their financial goals.
    Your approach is characterized by:
    1. Thorough analysis of each client's unique financial situation
    2. Clear and jargon-free communication of complex financial concepts
    3. Ethical considerations in all recommendations
    4. A focus on long-term financial health and stability

    Given the following client situation, provide a brief (3-4 sentences) financial advice:
    {client_situation}

    Your response should reflect your expertise and adhere to your characteristic approach."""
)

chain = financial_advisor_prompt | llm
response = chain.invoke({"client_situation": "A 35-year-old professional earning $80,000 annually, with $30,000 in savings, no debt, and no retirement plan."})
print(response.content)
# Out:
# Based on the client's situation, I would recommend that they prioritize building an emergency fund to cover 3-6 months of living expenses, which is currently lacking. Additionally, I would suggest exploring tax-advantaged retirement accounts such as a 401(k) or IRA, and contributing at least 10% of their income towards it. This will help them establish a solid foundation for long-term financial security and take advantage of compound interest to grow their savings over time. By starting early and being consistent, they can set themselves up for a more stable financial future.

# %% [markdown]
# ## Comparing Responsibilities in Different roles

# %%
roles = [
    ("Scientist", "You are a research scientist specializing in climate change. Explain the following concept in scientific terms:"),
    ("Teacher", "You are a middle school science teacher. Explain the following concept in simple terms suitable for 12-year-old students:"),
    ("Journalist", "You are a journalist writing for a popular science magazine. Explain the following concept in an engaging and informative manner for a general adult audience:")
]

topic = "The greenhouse effect"

for role, description in roles:
    role_prompt = PromptTemplate(
        input_variables=["topic"],
        template=f"{description} {{topic}}"
    )
    chain = role_prompt | llm
    response = chain.invoke({"topic": topic})
    print(f"\n{role}'s explanation:\n")
    print(response.content)
    print("-" * 50)
# Out:
# Scientist's explanation:
#
# The greenhouse effect is a complex, natural process that plays a crucial role in regulating Earth's temperature and maintaining a habitable environment for life on our planet.
#
# **Definition:** The greenhouse effect refers to the trapping of infrared radiation (heat) by certain gases present in the Earth's atmosphere. These gases, primarily carbon dioxide (CO2), methane (CH4), water vapor (H2O), and others, absorb and re-emit infrared radiation emitted by the Earth's surface, thereby warming the planet.
#
# **Mechanism:**
#
# 1. **Solar Radiation:** The sun emits solar radiation, which enters the Earth's atmosphere.
# 2. **Infrared Emission:** The Earth's surface absorbs solar radiation and converts it into heat energy, emitting infrared radiation (heat) back into the atmosphere.
# 3. **Greenhouse Gases:** Certain gases in the atmosphere, such as CO2, CH4, and H2O, absorb infrared radiation emitted by the Earth's surface.
# 4. **Trapping Heat:** These greenhouse gases re-emit the absorbed infrared radiation, trapping heat in the atmosphere and preventing it from escaping back into space.
#
# **Key Factors:**
#
# 1. **Concentration of Greenhouse Gases:** The concentration of greenhouse gases in the atmosphere affects the strength of the greenhouse effect. An increase in CO2 concentrations, for example, enhances the greenhouse effect.
# 2. **Temperature and Humidity:** Temperature and humidity levels influence the amount of infrared radiation emitted by the Earth's surface and absorbed by greenhouse gases.
# 3. **Atmospheric Pressure:** Changes in atmospheric pressure can affect the concentration of greenhouse gases and alter the strength of the greenhouse effect.
#
# **Natural vs. Anthropogenic Greenhouse Effect:**
#
# 1. **Natural Greenhouse Effect:** The natural greenhouse effect is a self-regulating process that maintains Earth's temperature within a narrow range, allowing life to thrive.
# 2. **Anthropogenic Greenhouse Effect:** Human activities, such as burning fossil fuels and deforestation, have increased the concentration of greenhouse gases in the atmosphere, amplifying the greenhouse effect and contributing to global warming.
#
# **Consequences:**
#
# 1. **Global Warming:** The enhanced greenhouse effect leads to an increase in Earth's average surface temperature, resulting in climate change.
# 2. **Climate Change Impacts:** Rising temperatures alter ecosystems, disrupt weather patterns, and exacerbate extreme weather events, such as heatwaves, droughts, and heavy precipitation.
#
# In conclusion, the greenhouse effect is a fundamental process that regulates Earth's temperature and maintains life on our planet. However, human activities have amplified this natural process, leading to climate change and its associated consequences. Understanding the greenhouse effect is crucial for developing effective strategies to mitigate and adapt to the impacts of climate change.
# --------------------------------------------------
#
# Teacher's explanation:
#
# Class! Today we're going to talk about something really cool - the greenhouse effect!
#
# So, you know how sometimes it gets really hot outside on a sunny day? That's because the sun is shining down on us and warming up the Earth. But did you know that the Earth has its own way of keeping warm too?
#
# The greenhouse effect is like a big blanket that wraps around the Earth. It's made up of special gases in the air, like carbon dioxide and water vapor, that trap heat from the sun.
#
# Here's how it works: when the sun shines down on the Earth, it warms up the air closest to the ground. This warm air rises up into the atmosphere, where it meets other gases like carbon dioxide and water vapor. These gases are like a big blanket that wraps around the Earth, trapping the heat from the sun.
#
# Think of it like this: imagine you're in a car on a sunny day with the windows rolled down. The sun's rays come in through the windows and warm up the air inside the car. If you roll up the windows, the heat gets trapped inside the car and makes it really hot! That's kind of what's happening with the greenhouse effect.
#
# But here's the thing: just like how you need to roll down your windows on a hot day, we need to find ways to reduce the amount of carbon dioxide and other gases in the air that trap heat. If we don't, the Earth can get too hot and cause problems like rising sea levels, more extreme weather events, and even droughts.
#
# So, what can we do? We can start by reducing our use of fossil fuels, like gasoline and coal, which release carbon dioxide into the air. We can also plant more trees and other plants that absorb carbon dioxide from the air. And we can try to reduce our waste and recycle more, so we don't produce as much trash.
#
# By working together, we can help keep the Earth cool and comfortable for everyone!
#
# Now, let's do a quick activity to see how the greenhouse effect works:
#
# * Take a small cup or container and fill it with hot water.
# * Place a clear plastic wrap over the top of the cup, making sure not to cover the bottom.
# * Observe what happens to the temperature inside the cup over time.
#
# This will help you visualize how the greenhouse effect works!
# --------------------------------------------------
#
# Journalist's explanation:
#
# **The Greenhouse Effect: How Our Planet's Temperature is Regulated**
#
# Imagine walking into a cozy, warm room on a chilly winter day. You feel comfortable, relaxed, and snug – just like you're wrapped in a warm hug. That's what the Earth's atmosphere does for us all year round, keeping our planet at a relatively stable temperature that allows life to thrive.
#
# But have you ever wondered how this magic happens? It's all thanks to a phenomenon called the greenhouse effect. In simple terms, it's like a natural thermostat that regulates the Earth's temperature, making sure we don't freeze or get too hot.
#
# **How Does it Work?**
#
# The greenhouse effect is named after the glass panels of greenhouses, which trap heat from the sun and keep plants warm. Similarly, our atmosphere acts as a blanket, trapping heat from the sun and preventing it from escaping into space.
#
# Here's what happens:
#
# 1. **Solar Radiation**: The sun emits solar radiation, which enters the Earth's atmosphere.
# 2. **Heat Absorption**: The atmosphere absorbs this radiation, warming up the air molecules.
# 3. **Infrared Radiation**: As the air warms up, it releases infrared radiation (heat) back into space.
# 4. **Greenhouse Effect**: The greenhouse gases in our atmosphere – like carbon dioxide, methane, and water vapor – trap some of this infrared radiation, preventing it from escaping.
#
# **The Perfect Balance**
#
# The Earth's atmosphere is designed to maintain a delicate balance between the amount of solar radiation that enters and the amount of heat that escapes. This balance ensures that we don't get too hot or too cold.
#
# However, human activities like burning fossil fuels, deforestation, and industrial processes have increased the concentration of greenhouse gases in our atmosphere. This has disrupted the natural balance, leading to an enhancement of the greenhouse effect – a phenomenon known as global warming.
#
# **The Consequences**
#
# As the Earth's temperature rises due to global warming, we're seeing more extreme weather events, melting glaciers, and rising sea levels. The consequences are far-reaching and devastating, affecting not only our planet but also the ecosystems that support us.
#
# **What Can We Do?**
#
# While the greenhouse effect is a natural process, human activities have amplified its effects. To mitigate global warming, we need to reduce our carbon footprint by:
#
# * Using renewable energy sources
# * Increasing energy efficiency
# * Protecting and reforestation efforts
# * Reducing waste and emissions
#
# By understanding the greenhouse effect and taking action to reduce our impact on the environment, we can help maintain a healthy balance between our planet's temperature and its natural thermostat – ensuring a sustainable future for generations to come.
#
# Stay informed, stay engaged, and let's work together to protect our planet!
# --------------------------------------------------
