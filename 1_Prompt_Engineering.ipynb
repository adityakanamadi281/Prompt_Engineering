# %% [markdown]
# # Introduction to Prompt Engineering

# %% [markdown]
# * Prompt engineering is the skill of writing clear and smart instructions to get the best answers from AI models.
# It helps guide tools like large language models to produce useful, accurate, and relevant results.
# In simple terms, it’s how we communicate effectively with AI to make it do what we want.

# %% [markdown]
# * Prompt engineering is the practice of designing and optimizing input prompts for language models to generate desired outputs. It's a crucial skill for effectively leveraging AI models in various applications.

# %% [markdown]
# ## Setup

# %%
from google.colab import userdata
api_key=userdata.get('OPENROUTER_API_KEY')

# %%
# !pip install langchain-openai
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-1.1.10-py3-none-any.whl.metadata (3.1 kB)
# Collecting langchain-core<2.0.0,>=1.2.13 (from langchain-openai)
#   Downloading langchain_core-1.2.13-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: openai<3.0.0,>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (2.21.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-openai) (0.7.3)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-openai) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-openai) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-openai) (0.14.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.20.0->langchain-openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.20.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.20.0->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.20.0->langchain-openai) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.20.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.20.0->langchain-openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=2.20.0->langchain-openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.20.0->langchain-openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.20.0->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=2.20.0->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.13->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-openai) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-openai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-openai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.13->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.13->langchain-openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.13->langchain-openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.5.0)
# Downloading langchain_openai-1.1.10-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.9 MB/s eta 0:00:00
# Downloading langchain_core-1.2.13-py3-none-any.whl (500 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.5/500.5 kB 26.4 MB/s eta 0:00:00
# Installing collected packages: langchain-core, langchain-openai
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.12
#     Uninstalling langchain-core-1.2.12:
#       Successfully uninstalled langchain-core-1.2.12
# Successfully installed langchain-core-1.2.13 langchain-openai-1.1.10

# %%
import os
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

# %%
llm = ChatOpenAI(
    model="mistralai/mistral-7b-instruct",
    base_url="https://openrouter.ai/api/v1",
    api_key=userdata.get("OPENROUTER_API_KEY"),
)

# %%
structured_prompt = PromptTemplate(
    input_variables=["topic"],
    template="Provide a definition of {topic}, explain its importance, and list three key benefits."
)

chain = structured_prompt | llm

input_variables = {"topic": "prompt engineering"}

output = chain.invoke(input_variables)

print(output.content)
# Out:
# ### **Prompt Engineering: Definition, Importance, and Key Benefits**
#
# #### **Definition:**
# **Prompt engineering** is the practice of designing, refining, and optimizing text-based inputs (called *prompts*) to generate more accurate, creative, and useful responses from AI language models (e.g., LLMs like GPT-4). It involves structuring prompts with clarity, specificity, and context to guide the AI toward desired outputs, balancing between technical precision and natural language fluency.
#
# Key aspects include:
# - **Crafting effective queries** (e.g., using instructions, examples, or constraints).
# - **Iterative testing and refinement** to improve AI performance.
# - **Understanding model limitations** (e.g., hallucinations, bias) and mitigating them through prompt design.
#
# ---
#
# #### **Importance:**
# Prompt engineering bridges the gap between raw AI capabilities and practical, human-aligned applications. It is critical because:
# 1. **AI models are not fully "understanding"** – They rely on statistical patterns in training data rather than true comprehension, so well-structured prompts help steer their behavior.
# 2. **Output quality depends on input quality** – A poorly designed prompt can lead to irrelevant, biased, or nonsensical responses, while a good prompt enhances relevance, coherence, and utility.
# 3. **Cost and efficiency** – Optimized prompts reduce the need for expensive fine-tuning or multiple iterations, making AI interactions faster and more resource-effective.
# 4. **Customization for tasks** – Different applications (e.g., chatbots, coding assistants, content generation) require tailored prompts to achieve specific goals.
# 5. **Mitigating risks** – It helps control hallucinations, toxic outputs, and misinformation by providing guardrails (e.g., "Be concise," "Cite sources," or "Avoid speculative answers").
#
# ---
# #### **Three Key Benefits:**
# 1. **Improved Accuracy & Relevance**
#    - Well-engineered prompts (e.g., with clear instructions, examples, or constraints) yield more precise, fact-based, and task-specific responses.
#    - Example: Adding *"Explain this in simple terms for a 10-year-old"* improves clarity over vague queries.
#
# 2. **Enhanced Creativity & Control**
#    - Prompts can guide AI toward creative solutions while limiting undesired outputs (e.g., bias, off-topic answers).
#    - Example: Using *"Write a poem about climate change in the style of Emily Dickinson"* generates stylistically consistent creative content.
#
# 3. **Reduced Development Costs**
#    - Instead of training custom models, prompt engineering leverages existing AI (like GPT) with minimal adjustments, saving time and computational resources.
#    - Example: A chatbot can be fine-tuned via prompts rather than full model retraining for niche industries (e.g., legal or medical jargon).
#
# ---
# #### **Bonus Insight:**
# Prompt engineering is evolving with techniques like **chain-of-thought (CoT) prompting**, **few-shot learning**, and **role-playing prompts** to further refine AI interactions. As models become more advanced, mastering this skill will be essential for maximizing their potential across domains.

# %%
prompts = [
    "List 3 applications of AI in healthcare.",
    "Explain how AI is revolutionizing healthcare, with 3 specific examples.",
    "You are a doctor. Describe 3 ways AI has improved your daily work in the hospital."
]

for i, prompt in enumerate(prompts, 1):
    print(f"\nPrompt {i}:")
    print(prompt)
    print("\nResponse:")
    print(llm.invoke(prompt).content)
    print("-" * 50)
# Out:
# Prompt 1:
# List 3 applications of AI in healthcare.
#
# Response:
# Artificial Intelligence (AI) is transforming healthcare in numerous ways, improving diagnostics, treatment, patient care, and operational efficiency. Here are **three key applications of AI in healthcare**:
#
# ### 1. **Medical Imaging & Diagnostics**
#    - **AI-powered radiology & pathology**: AI algorithms (e.g., deep learning models) analyze X-rays, MRIs, CT scans, and other imaging data to detect abnormalities like tumors, fractures, or signs of diseases (e.g., cancer, Alzheimer’s) with high accuracy. Examples include:
#      - **Google DeepMind’s AI** (used in partnership with hospitals to analyze retinal scans for diabetic eye disease).
#      - **IBM Watson Health** (assists in cancer diagnosis by interpreting genomic and imaging data).
#      - **Automated detection of pneumonia** (AI tools like those from **Lunit** or **Aidoc** flag lung infections in chest X-rays faster than radiologists).
#    - **Early disease detection**: AI can identify subtle patterns in imaging that humans might miss, enabling earlier intervention (e.g., AI detecting breast cancer in mammograms or skin cancer in dermatology images).
#    - **Reduced diagnostic errors**: AI acts as a second opinion, improving consistency and reducing false negatives/positives.
#
# ### 2. **Personalized Medicine & Treatment Optimization**
#    - **Genomic & drug discovery**: AI accelerates drug development by analyzing vast datasets (e.g., protein structures, clinical trials) to predict drug interactions, identify new compounds, or repurpose existing drugs. Examples:
#      - **AlphaFold (DeepMind)** – Predicts protein folding, aiding in understanding disease mechanisms and drug design.
#      - **AI in oncology** – Tools like **Tempus** or **Guardant Health** use AI to match patients with precision therapies based on genetic markers.
#      - **Personalized treatment plans** – AI models (e.g., **Flatiron Health’s AI**) recommend tailored cancer treatments by analyzing patient data.
#    - **Predictive analytics**: AI forecasts patient outcomes (e.g., risk of readmission, disease progression) using electronic health records (EHRs), lab results, and lifestyle data. Example:
#      - **IBM Watson for Oncology** – Helps oncologists predict how a patient will respond to treatment.
#    - **Chronic disease management**: AI-powered wearables (e.g., **Apple Watch’s irregular rhythm notifications**) or apps monitor conditions like diabetes, heart disease, or Parkinson’s, adjusting insulin doses or alerting doctors to anomalies.
#
# ### 3. **Administrative & Operational Efficiency**
#    - **Automated patient scheduling & resource allocation**: AI optimizes hospital workflows by predicting patient influx, staffing needs, and appointment scheduling to reduce wait times. Examples:
#      - **Microsoft’s AI for hospital bed management** – Predicts patient admissions to improve bed allocation.
#      - **AI chatbots (e.g., **Buoy Health, Ada Health**) – Triaging patients by answering initial questions and directing them to appropriate care.
#    - **Fraud detection & insurance claims**: AI analyzes billing patterns to identify fraudulent claims, saving healthcare providers millions. Example:
#      - **Optum’s AI** – Detects anomalies in insurance claims to prevent overbilling.
#    - **Drug supply chain optimization**: AI predicts demand for medications, reducing waste and ensuring availability. Example:
#      - **McKesson’s AI** – Manages pharmacy inventory and automates order fulfillment.
#    - **Clinical decision support**: AI systems (e.g., **Epic’s AI**) assist doctors in real-time by suggesting diagnoses, treatment options, or dosage adjustments based on EHRs.
#
# ### **Bonus Applications (for broader context)**:
#    - **AI in mental health** – Chatbots like **Woebot** or ** Wysa** provide therapy, monitor mood, and suggest coping strategies.
#    - **AI-driven surgical robots** – Systems like **da Vinci** (with AI enhancements) assist in minimally invasive surgeries with precision.
#    - **AI for virtual nursing assistants** – Tools like **Amazon Alexa’s healthcare skills** or **Google’s Med-PaLM** help answer medical questions and manage appointments.
#
# Would you like details on any specific application?
# --------------------------------------------------
#
# Prompt 2:
# Explain how AI is revolutionizing healthcare, with 3 specific examples.
#
# Response:
# Artificial Intelligence (AI) is transforming healthcare by enhancing diagnostics, personalizing treatment, improving operational efficiency, and enabling predictive analytics. Here are **three specific examples** of how AI is revolutionizing the industry:
#
# ### 1. **AI-Powered Medical Imaging & Diagnostics**
#    AI is dramatically improving the accuracy and speed of medical imaging analysis, reducing human error and enabling early detection of diseases.
#    - **Example: Deep Learning for Cancer Detection**
#      AI models, particularly **deep learning-based tools**, can analyze X-rays, MRIs, CT scans, and even histopathology slides to detect abnormalities like tumors with **higher precision than radiologists in some cases**.
#      - **Google’s DeepMind** (now part of **Google Health**) developed an AI that outperformed human experts in identifying **diabetic retinopathy** (a leading cause of blindness) from retinal scans, flagging cases with **94% accuracy** compared to 87% for clinicians.
#      - **IBM Watson Health** assists in **breast cancer detection** by analyzing mammograms and providing second opinions to radiologists, reducing false negatives.
#      - **PathAI** uses AI to analyze **biopsy images** and help pathologists detect **prostate and breast cancers** more accurately, improving early diagnosis and treatment planning.
#    - **Impact:** Faster, more reliable diagnoses; reduced workload for medical professionals; and earlier intervention, saving lives.
#
# ### 2. **Personalized Medicine & Drug Discovery**
#    AI is enabling **precision medicine** by tailoring treatments to individual genetic profiles and accelerating drug development.
#    - **Example: AI in Genomic Analysis & Treatment Recommendations**
#      - **IBM Watson for Oncology** analyzes a patient’s **genetic makeup, medical history, and treatment options** to suggest **personalized cancer therapies**, reducing trial-and-error in chemotherapy and immunotherapy.
#      - **Tempus** (a clinical AI company) uses **machine learning to process genomic and clinical data**, helping oncologists recommend the **best drug combinations** for patients based on real-world outcomes.
#    - **Example: AI-Driven Drug Discovery**
#      - **AlphaFold (DeepMind)** revolutionized **protein folding prediction**, allowing researchers to simulate how proteins interact with drugs. This has **cut drug discovery timelines by years**—e.g., helping **Insilico Medicine** design a potential **COVID-19 drug** in weeks.
#      - **BenevolentAI’s AI platform** identified **baricitinib**, a drug now used to treat **rheumatoid arthritis**, by analyzing **biological pathways and scientific literature** that humans might have missed.
#    - **Impact:** More effective treatments with fewer side effects; **faster development of life-saving drugs**; and reduced costs for pharmaceutical companies.
#
# ### 3. **AI in Predictive & Preventive Healthcare**
#    AI is shifting healthcare from **reactive to proactive** by predicting disease risks, optimizing patient care, and reducing hospital readmissions.
#    - **Example: Predictive Analytics for Chronic Disease Management**
#      - **Flatiron Health’s AI (now Roche)** analyzes **electronic health records (EHRs)** to predict which **cancer patients are at high risk of relapse**, allowing doctors to adjust treatments preemptively.
#      - **DeepMind’s Stroke Prediction Model** (in partnership with **NHS**) can **identify patients likely to have a stroke within a year** by analyzing routine health data, enabling early preventive care.
#    - **Example: AI Chatbots & Virtual Health Assistants**
#      - **Woebot** (an AI-powered chatbot) provides **mental health support** using **cognitive behavioral therapy (CBT)** techniques, helping users manage anxiety and depression between therapy sessions.
#      - **Ada Health’s AI assistant** triages **symptoms and suggests treatments** (or when to see a doctor) based on user input, improving **primary care efficiency** in regions with doctor shortages.
#    - **Impact:** **Lower healthcare costs** through early intervention; **reduced hospital burdens** by preventing avoidable admissions; and **better patient outcomes** with tailored preventive care.
#
# ### **Bonus: AI in Administrative & Operational Efficiency**
#    - **Example: Automated Medical Coding & Fraud Detection**
#      - **Nuance’s AI (Dragon Medical)** automates **medical transcription**, saving doctors **hours per week** and reducing administrative errors.
#      - **Ayasdi (now part of **Boehringer Ingelheim**) uses AI to detect **healthcare fraud patterns** in insurance claims, saving billions in losses.
#    - **Impact:** **Faster billing and claims processing**; **lower costs** for hospitals and insurers; and **more time for doctors to focus on patient care**.
#
# ### **Why AI is a Game-Changer in Healthcare**
# - **Speed & Scale:** AI can process **millions of data points** (from EHRs, wearables, and imaging) in seconds, far beyond human capacity.
# - **Reduced Bias:** When trained on **diverse datasets**, AI can help **minimize diagnostic disparities** (e.g., better detection in underrepresented populations).
# - **Cost Savings:** Early disease detection and **optimized treatments** reduce long-term healthcare expenses.
# - **Patient Empowerment:** AI-driven tools (like **chatbots and remote monitoring**) make healthcare more **accessible and personalized**.
#
# Would you like a deeper dive into any of these applications?
# --------------------------------------------------
#
# Prompt 3:
# You are a doctor. Describe 3 ways AI has improved your daily work in the hospital.
#
# Response:
# As a doctor, AI (Artificial Intelligence) has become an invaluable tool in enhancing efficiency, accuracy, and patient care in my daily work. Here are three key ways AI has improved my routine in the hospital:
#
# ### 1. **Diagnostic Assistance & Early Detection**
#    - **Faster & More Accurate Diagnoses**: AI-powered tools like **radiology imaging analysis (e.g., deep learning models for X-rays, MRIs, or CT scans)** help me detect abnormalities (e.g., tumors, fractures, or infections) with higher precision than ever before. For example, AI can flag subtle signs of pneumonia in chest X-rays or identify early-stage diabetic retinopathy in retinal scans, reducing missed cases and speeding up decision-making.
#    - **Predictive Analytics**: AI models analyze patient data (lab results, vitals, past medical history) to **predict risks** (e.g., sepsis, heart failure, or stroke) before symptoms fully manifest. This allows for **proactive interventions**, such as adjusting medication or monitoring high-risk patients more closely, improving outcomes.
#    - **Differential Diagnosis Support**: Natural language processing (NLP) tools (e.g., **IBM Watson, DeepMind’s AlphaMiss**) assist in generating **differential diagnoses** based on patient symptoms, lab findings, and medical literature. While I still make the final call, AI helps me consider rarer conditions I might overlook, especially in complex cases.
#
# ### 2. **Streamlining Administrative & Clinical Workflows**
#    - **Automated Documentation & Note-Taking**: AI-driven **voice-to-text transcription** (e.g., Nuance’s **Dragon Medical**) and **smart EHR (Electronic Health Record) systems** reduce the time I spend typing progress notes, allowing me to focus more on patient interaction. Some AI tools even **summarize consultations** or suggest follow-up plans based on templates.
#    - **Appointment & Resource Optimization**: AI algorithms help **schedule appointments** by analyzing patient urgency, doctor availability, and hospital capacity. For example, **Google’s DeepMind** has been used to optimize MRI wait times, ensuring critical patients get scans faster. AI also predicts **bed occupancy** and **staffing needs**, reducing bottlenecks in patient flow.
#    - **Medication & Treatment Recommendations**: AI systems like **Epic’s Beacon** or **UpToDate’s AI-assisted drug interaction checker** flag **potential adverse drug reactions**, suggest **evidence-based treatment options**, and even optimize dosing for conditions like diabetes or anticoagulation. This minimizes errors and improves compliance with best practices.
#
# ### 3. **Personalized Patient Care & Decision Support**
#    - **Tailored Treatment Plans**: AI analyzes **genomic data, lifestyle factors, and response to previous treatments** to recommend **personalized medicine** (e.g., cancer therapy, chronic disease management). For instance, **AI-driven precision oncology tools** help match patients with targeted treatments based on their tumor profiles, improving efficacy and reducing side effects.
#    - **Remote Monitoring & Telemedicine**: AI-powered **wearable devices (e.g., Apple Watch, continuous glucose monitors)** and **telehealth platforms** allow me to track patients’ vitals and symptoms in real time. For example, AI can alert me if a post-op patient’s heart rate or oxygen levels drop unexpectedly, enabling **early intervention** without waiting for in-person visits.
#    - **Patient Risk Stratification**: AI models (e.g., **IBM’s AI for sepsis prediction**) assess **individual patient risks** (e.g., readmission, complications) by integrating data from multiple sources. This helps me prioritize care, allocate resources efficiently, and **reduce preventable hospitalizations**.
#
# ### **Bonus: AI in Education & Training**
#    - **Continuous Learning**: AI tools like **ChatGPT (for research queries)** or **specialized medical AI assistants** help me stay updated on **new guidelines, clinical trials, and emerging treatments** without manually sifting through thousands of papers.
#    - **Simulations & VR Training**: AI-enhanced **virtual reality (VR) simulations** (e.g., for surgical training) or **case-based learning platforms** allow me to practice rare procedures (e.g., robotic surgery, trauma cases) in a risk-free environment, improving my skills before treating real patients.
#
# ### **Challenges & Considerations**
# While AI brings immense benefits, I still **verify all AI-generated insights** with clinical judgment and peer review. Key challenges include:
#    - **Data Privacy & Bias**: Ensuring AI models are trained on **diverse, unbiased datasets** to avoid disparities in care.
#    - **Over-Reliance Risks**: AI is not infallible—it can miss nuanced human context (e.g., patient anxiety, subtle physical exam findings).
#    - **Integration with Workflow**: Some AI tools require **additional training** or **seamless EHR integration** to be truly useful.
#
# ### **Future Potential**
# I’m excited about AI’s role in **automated imaging reporting**, **AI-assisted robotic surgery**, and **real-time diagnostic support during procedures**. As AI evolves, it may even help in **drug discovery** and **personalized follow-up care**, further revolutionizing medicine.
#
# Would you like me to elaborate on any specific area (e.g., AI in radiology, ICU monitoring, or mental health)?
# --------------------------------------------------

# %%
fact_check_prompt = PromptTemplate(
    input_variables=["statement"],
    template="""Evaluate the following statement for factual accuracy. If it's incorrect, provide the correct information:
    Statement: {statement}
    Evaluation:"""
)

chain = fact_check_prompt | llm
print(chain.invoke("The capital of France is London.").content)
# Out:
# The statement **"The capital of France is London"** is **incorrect**.
#
# The correct capital of France is **Paris**. London is the capital of the **United Kingdom** (not France), which includes England, Scotland, Wales, and Northern Ireland.
#
# Would you like any additional details about France's geography, history, or political structure?

# %%
problem_solving_prompt = PromptTemplate(
    input_variables=["problem"],
    template="""Solve the following problem step by step:
    Problem: {problem}
    Solution:
    1)"""
)

chain = problem_solving_prompt | llm
print(chain.invoke("Calculate the compound interest on $1000 invested for 5 years at an annual rate of 5%, compounded annually.").content)
# Out:
# To calculate the compound interest on an investment, we use the formula for compound interest:
#
# \[ A = P \left(1 + \frac{r}{n}\right)^{nt} \]
#
# Where:
# - \( A \) is the amount of money accumulated after n years, including interest.
# - \( P \) is the principal amount (the initial amount of money).
# - \( r \) is the annual interest rate (decimal).
# - \( n \) is the number of times that interest is compounded per year.
# - \( t \) is the time the money is invested for, in years.
#
# In this problem:
# - \( P = \$1000 \)
# - \( r = 5\% = 0.05 \)
# - \( n = 1 \) (compounded annually)
# - \( t = 5 \) years
#
# Since the interest is compounded annually, \( n = 1 \). The formula simplifies to:
#
# \[ A = P (1 + r)^t \]
#
# Now, we substitute the values into the formula:
#
# 1) Calculate \( (1 + r) \):
# \[ 1 + 0.05 = 1.05 \]
#
# 2) Raise \( (1 + r) \) to the power of \( t \):
# \[ (1.05)^5 \]
#
# To calculate \( (1.05)^5 \), we can use the power rule step by step:
# \[ (1.05)^1 = 1.05 \]
# \[ (1.05)^2 = 1.05 \times 1.05 = 1.1025 \]
# \[ (1.05)^3 = 1.1025 \times 1.05 \approx 1.1576 \]
# \[ (1.05)^4 = 1.1576 \times 1.05 \approx 1.2155 \]
# \[ (1.05)^5 = 1.2155 \times 1.05 \approx 1.2763 \]
#
# 3) Multiply the principal amount \( P \) by the result from step 2:
# \[ A = 1000 \times 1.2763 \approx 1276.28 \]
#
# 4) Calculate the compound interest by subtracting the principal amount from the accumulated amount:
# \[ \text{Compound Interest} = A - P \]
# \[ \text{Compound Interest} = 1276.28 - 1000 = 276.28 \]
#
# The compound interest on $1000 invested for 5 years at an annual rate of 5%, compounded annually is approximately $276.28.
